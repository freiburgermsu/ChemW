# %%
# load a COBRA model

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the models
import cobrakbase
token = '4GBQCLKV4Z7OOJZMI43UB27QIPGS353I'
kbase_api = cobrakbase.KBaseAPI(token)
model1 = kbase_api.get_from_ws("iML1515",76994)
# model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
# Out:
# cobrakbase 0.2.8
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd11416_c0]: not found

# %% [markdown]
# # Calculate the MW from all metabolite formulae

# %%
# from chemw import ChemMW 
# %run ../../chemw/mw.py
chem_mw = ChemMW()
for met in model1.metabolites:
    print('\n',met.formula)
    print(met.elements)
    chem_mw.mass(met.formula)
# Out:
#  C12H14N2O2
# {'C': 12, 'H': 14, 'N': 2, 'O': 2}
# C12H14N2O2 --- MW (amu): 218.252
#
#  CHO3
# {'C': 1, 'H': 1, 'O': 3}
# CHO3 --- MW (amu): 61.0168
#
#  C77H119N15O41
# {'C': 77, 'H': 119, 'N': 15, 'O': 41}
# C77H119N15O41 --- MW (amu): 1910.84
#
#  C2H3O5P
# {'C': 2, 'H': 3, 'O': 5, 'P': 1}
# C2H3O5P --- MW (amu): 138.016
#
#  C29H38N7O17P3S
# {'C': 29, 'H': 38, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C29H38N7O17P3S --- MW (amu): 881.64
#
#  *
# {}
#
#  C17H29N2O8PRS
# {'C': 17, 'H': 29, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C17H29N2O8PRS --- MW (amu): 452.46
#
#  C8H12NO
# {'C': 8, 'H': 12, 'N': 1, 'O': 1}
# C8H12NO --- MW (amu): 138.19
#
#  H2O3PSe
# {'H': 2, 'O': 3, 'P': 1, 'Se': 1}
# H2O3PSe --- MW (amu): 159.9
#
#  C8H12N
# {'C': 8, 'H': 12, 'N': 1}
# C8H12N --- MW (amu): 122.2
#
#  C5H9O7P
# {'C': 5, 'H': 9, 'O': 7, 'P': 1}
# C5H9O7P --- MW (amu): 212.1
#
#  C7H3NO4
# {'C': 7, 'H': 3, 'N': 1, 'O': 4}
# C7H3NO4 --- MW (amu): 165.1
#
#  C8H12N
# {'C': 8, 'H': 12, 'N': 1}
# C8H12N --- MW (amu): 122.2
#
#  *
# {}
#
#  *
# {}
#
#  C5H16N2
# {'C': 5, 'H': 16, 'N': 2}
# C5H16N2 --- MW (amu): 104.2
#
#  C5H16N2
# {'C': 5, 'H': 16, 'N': 2}
# C5H16N2 --- MW (amu): 104.2
#
#  C5H16N2
# {'C': 5, 'H': 16, 'N': 2}
# C5H16N2 --- MW (amu): 104.2
#
#  Cs
# {'Cs': 1}
# Cs --- MW (amu): 132.9
#
#  C6H14O8P
# {'C': 6, 'H': 14, 'O': 8, 'P': 1}
# C6H14O8P --- MW (amu): 245.1
#
#  C31H56O8P
# {'C': 31, 'H': 56, 'O': 8, 'P': 1}
# C31H56O8P --- MW (amu): 587.7
#
#  C31H47O6
# {'C': 31, 'H': 47, 'O': 6}
# C31H47O6 --- MW (amu): 515.7
#
#  *
# {}
#
#  C19H19N7O6
# {'C': 19, 'H': 19, 'N': 7, 'O': 6}
# C19H19N7O6 --- MW (amu): 441.4
#
#  C11H15N5O3S
# {'C': 11, 'H': 15, 'N': 5, 'O': 3, 'S': 1}
# C11H15N5O3S --- MW (amu): 297.3
#
#  C35H68O5
# {'C': 35, 'H': 68, 'O': 5}
# C35H68O5 --- MW (amu): 568.9
#
#  C31H56O8P
# {'C': 31, 'H': 56, 'O': 8, 'P': 1}
# C31H56O8P --- MW (amu): 587.7
#
#  C6H9O7
# {'C': 6, 'H': 9, 'O': 7}
# C6H9O7 --- MW (amu): 193.1
#
#  Fe2S2
# {'Fe': 2, 'S': 2}
# Fe2S2 --- MW (amu): 175.8
#
#  C8H8O2
# {'C': 8, 'H': 8, 'O': 2}
# C8H8O2 --- MW (amu): 136.1
#
#  C4H4O5
# {'C': 4, 'H': 4, 'O': 5}
# C4H4O5 --- MW (amu): 132.1
#
#  C9H9O4
# {'C': 9, 'H': 9, 'O': 4}
# C9H9O4 --- MW (amu): 181.2
#
#  C4H4O5
# {'C': 4, 'H': 4, 'O': 5}
# C4H4O5 --- MW (amu): 132.1
#
#  C7H5O3
# {'C': 7, 'H': 5, 'O': 3}
# C7H5O3 --- MW (amu): 137.1
#
#  C6H11N3O4P
# {'C': 6, 'H': 11, 'N': 3, 'O': 4, 'P': 1}
# C6H11N3O4P --- MW (amu): 220.1
#
#  C40H74O10P
# {'C': 40, 'H': 74, 'O': 10, 'P': 1}
# C40H74O10P --- MW (amu): 746.0
#
#  C69H113NO16P2
# {'C': 69, 'H': 113, 'N': 1, 'O': 16, 'P': 2}
# C69H113NO16P2 --- MW (amu): 1275
#
#  *
# {}
#
#  C35H68O5
# {'C': 35, 'H': 68, 'O': 5}
# C35H68O5 --- MW (amu): 568.9
#
#  C25H49N6O8
# {'C': 25, 'H': 49, 'N': 6, 'O': 8}
# C25H49N6O8 --- MW (amu): 561.7
#
#  C57H108O17P2
# {'C': 57, 'H': 108, 'O': 17, 'P': 2}
# C57H108O17P2 --- MW (amu): 1127
#
#  C123H200N2O57P2
# {'C': 123, 'H': 200, 'N': 2, 'O': 57, 'P': 2}
# C123H200N2O57P2 --- MW (amu): 2681
#
#  C25H49N6O8
# {'C': 25, 'H': 49, 'N': 6, 'O': 8}
# C25H49N6O8 --- MW (amu): 561.7
#
#  C9H15NO8P
# {'C': 9, 'H': 15, 'N': 1, 'O': 8, 'P': 1}
# C9H15NO8P --- MW (amu): 296.2
#
#  C25H49N6O8
# {'C': 25, 'H': 49, 'N': 6, 'O': 8}
# C25H49N6O8 --- MW (amu): 561.7
#
#  *
# {}
#
#  C8H8O2
# {'C': 8, 'H': 8, 'O': 2}
# C8H8O2 --- MW (amu): 136.1
#
#  C14H18N2O4
# {'C': 14, 'H': 18, 'N': 2, 'O': 4}
# C14H18N2O4 --- MW (amu): 278.3
#
#  C25H45N2O8PRS
# {'C': 25, 'H': 45, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C25H45N2O8PRS --- MW (amu): 564.7
#
#  C31H47O6
# {'C': 31, 'H': 47, 'O': 6}
# C31H47O6 --- MW (amu): 515.7
#
#  C4H4O5
# {'C': 4, 'H': 4, 'O': 5}
# C4H4O5 --- MW (amu): 132.1
#
#  *
# {}
#
#  C11H12NO9P
# {'C': 11, 'H': 12, 'N': 1, 'O': 9, 'P': 1}
# C11H12NO9P --- MW (amu): 333.2
#
#  C6H13NO8P
# {'C': 6, 'H': 13, 'N': 1, 'O': 8, 'P': 1}
# C6H13NO8P --- MW (amu): 258.1
#
#  C17H25N3O17P2
# {'C': 17, 'H': 25, 'N': 3, 'O': 17, 'P': 2}
# C17H25N3O17P2 --- MW (amu): 605.3
#
#  C6H13NO8P
# {'C': 6, 'H': 13, 'N': 1, 'O': 8, 'P': 1}
# C6H13NO8P --- MW (amu): 258.1
#
#  C39H65N7O17P3S
# {'C': 39, 'H': 65, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C39H65N7O17P3S --- MW (amu): 1029
#
#  C6H13NO8P
# {'C': 6, 'H': 13, 'N': 1, 'O': 8, 'P': 1}
# C6H13NO8P --- MW (amu): 258.1
#
#  C24H36N7O17P3S
# {'C': 24, 'H': 36, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C24H36N7O17P3S --- MW (amu): 819.6
#
#  C3H8O2
# {'C': 3, 'H': 8, 'O': 2}
# C3H8O2 --- MW (amu): 76.09
#
#  C29H44N7O17P3S
# {'C': 29, 'H': 44, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C29H44N7O17P3S --- MW (amu): 887.7
#
#  C10H17N2O3
# {'C': 10, 'H': 17, 'N': 2, 'O': 3}
# C10H17N2O3 --- MW (amu): 213.3
#
#  *
# {}
#
#  C17H19N4O6
# {'C': 17, 'H': 19, 'N': 4, 'O': 6}
# C17H19N4O6 --- MW (amu): 375.4
#
#  C24H46O9P
# {'C': 24, 'H': 46, 'O': 9, 'P': 1}
# C24H46O9P --- MW (amu): 509.6
#
#  C4H7O7P
# {'C': 4, 'H': 7, 'O': 7, 'P': 1}
# C4H7O7P --- MW (amu): 198.1
#
#  C10H11N4O7P
# {'C': 10, 'H': 11, 'N': 4, 'O': 7, 'P': 1}
# C10H11N4O7P --- MW (amu): 330.2
#
#  C6H12O5
# {'C': 6, 'H': 12, 'O': 5}
# C6H12O5 --- MW (amu): 164.2
#
#  C6H12O5
# {'C': 6, 'H': 12, 'O': 5}
# C6H12O5 --- MW (amu): 164.2
#
#  C10H11N4O7P
# {'C': 10, 'H': 11, 'N': 4, 'O': 7, 'P': 1}
# C10H11N4O7P --- MW (amu): 330.2
#
#  C41H82NO8P
# {'C': 41, 'H': 82, 'N': 1, 'O': 8, 'P': 1}
# C41H82NO8P --- MW (amu): 748.1
#
#  C6H11O7
# {'C': 6, 'H': 11, 'O': 7}
# C6H11O7 --- MW (amu): 195.1
#
#  C74H112N14O39
# {'C': 74, 'H': 112, 'N': 14, 'O': 39}
# C74H112N14O39 --- MW (amu): 1822
#
#  C21H44NO7P
# {'C': 21, 'H': 44, 'N': 1, 'O': 7, 'P': 1}
# C21H44NO7P --- MW (amu): 453.6
#
#  C41H82NO8P
# {'C': 41, 'H': 82, 'N': 1, 'O': 8, 'P': 1}
# C41H82NO8P --- MW (amu): 748.1
#
#  C49H76O4
# {'C': 49, 'H': 76, 'O': 4}
# C49H76O4 --- MW (amu): 729.1
#
#  C5H10O7P2
# {'C': 5, 'H': 10, 'O': 7, 'P': 2}
# C5H10O7P2 --- MW (amu): 244.1
#
#  C27H50N2O9PRS
# {'C': 27, 'H': 50, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C27H50N2O9PRS --- MW (amu): 609.7
#
#  C6H12O5
# {'C': 6, 'H': 12, 'O': 5}
# C6H12O5 --- MW (amu): 164.2
#
#  C17H36N6O5S
# {'C': 17, 'H': 36, 'N': 6, 'O': 5, 'S': 1}
# C17H36N6O5S --- MW (amu): 436.6
#
#  C5H9NO3
# {'C': 5, 'H': 9, 'N': 1, 'O': 3}
# C5H9NO3 --- MW (amu): 131.1
#
#  C21H44NO7P
# {'C': 21, 'H': 44, 'N': 1, 'O': 7, 'P': 1}
# C21H44NO7P --- MW (amu): 453.6
#
#  *
# {}
#
#  *
# {}
#
#  C12H17N4O7P2S
# {'C': 12, 'H': 17, 'N': 4, 'O': 7, 'P': 2, 'S': 1}
# C12H17N4O7P2S --- MW (amu): 423.3
#
#  C8H20NO6P
# {'C': 8, 'H': 20, 'N': 1, 'O': 6, 'P': 1}
# C8H20NO6P --- MW (amu): 257.2
#
#  *
# {}
#
#  C17H19N4O6
# {'C': 17, 'H': 19, 'N': 4, 'O': 6}
# C17H19N4O6 --- MW (amu): 375.4
#
#  *
# {}
#
#  *
# {}
#
#  *
# {}
#
#  C32H39N7O20P3S
# {'C': 32, 'H': 39, 'N': 7, 'O': 20, 'P': 3, 'S': 1}
# C32H39N7O20P3S --- MW (amu): 966.7
#
#  C8H14NO9P
# {'C': 8, 'H': 14, 'N': 1, 'O': 9, 'P': 1}
# C8H14NO9P --- MW (amu): 299.2
#
#  C8H14NO9P
# {'C': 8, 'H': 14, 'N': 1, 'O': 9, 'P': 1}
# C8H14NO9P --- MW (amu): 299.2
#
#  C5H9O6
# {'C': 5, 'H': 9, 'O': 6}
# C5H9O6 --- MW (amu): 165.1
#
#  C6H11O4
# {'C': 6, 'H': 11, 'O': 4}
# C6H11O4 --- MW (amu): 147.1
#
#  C10H12N5O6P
# {'C': 10, 'H': 12, 'N': 5, 'O': 6, 'P': 1}
# C10H12N5O6P --- MW (amu): 329.2
#
#  C8H14NO9P
# {'C': 8, 'H': 14, 'N': 1, 'O': 9, 'P': 1}
# C8H14NO9P --- MW (amu): 299.2
#
#  C5H9O6
# {'C': 5, 'H': 9, 'O': 6}
# C5H9O6 --- MW (amu): 165.1
#
#  C71H113N2O18P2
# {'C': 71, 'H': 113, 'N': 2, 'O': 18, 'P': 2}
# C71H113N2O18P2 --- MW (amu): 1345
#
#  C5H9O6
# {'C': 5, 'H': 9, 'O': 6}
# C5H9O6 --- MW (amu): 165.1
#
#  C5H3N2O4
# {'C': 5, 'H': 3, 'N': 2, 'O': 4}
# C5H3N2O4 --- MW (amu): 155.1
#
#  C6H8NO4PS
# {'C': 6, 'H': 8, 'N': 1, 'O': 4, 'P': 1, 'S': 1}
# C6H8NO4PS --- MW (amu): 221.2
#
#  C5H3N2O4
# {'C': 5, 'H': 3, 'N': 2, 'O': 4}
# C5H3N2O4 --- MW (amu): 155.1
#
#  C3H4O7P
# {'C': 3, 'H': 4, 'O': 7, 'P': 1}
# C3H4O7P --- MW (amu): 183.0
#
#  C5H3N2O4
# {'C': 5, 'H': 3, 'N': 2, 'O': 4}
# C5H3N2O4 --- MW (amu): 155.1
#
#  C12H17N4OS
# {'C': 12, 'H': 17, 'N': 4, 'O': 1, 'S': 1}
# C12H17N4OS --- MW (amu): 265.4
#
#  C10H12N5O7P
# {'C': 10, 'H': 12, 'N': 5, 'O': 7, 'P': 1}
# C10H12N5O7P --- MW (amu): 345.2
#
#  C12H17N4OS
# {'C': 12, 'H': 17, 'N': 4, 'O': 1, 'S': 1}
# C12H17N4OS --- MW (amu): 265.4
#
#  C10H12N5O7P
# {'C': 10, 'H': 12, 'N': 5, 'O': 7, 'P': 1}
# C10H12N5O7P --- MW (amu): 345.2
#
#  C21H33N7O13P2S
# {'C': 21, 'H': 33, 'N': 7, 'O': 13, 'P': 2, 'S': 1}
# C21H33N7O13P2S --- MW (amu): 685.5
#
#  C12H17N4OS
# {'C': 12, 'H': 17, 'N': 4, 'O': 1, 'S': 1}
# C12H17N4OS --- MW (amu): 265.4
#
#  C17H32O7P
# {'C': 17, 'H': 32, 'O': 7, 'P': 1}
# C17H32O7P --- MW (amu): 379.4
#
#  C5H10BO7
# {'C': 5, 'H': 10, 'B': 1, 'O': 7}
# C5H10BO7 --- MW (amu): 192.9
#
#  C7H5NO4
# {'C': 7, 'H': 5, 'N': 1, 'O': 4}
# C7H5NO4 --- MW (amu): 167.1
#
#  *
# {}
#
#  C5H10O5
# {'C': 5, 'H': 10, 'O': 5}
# C5H10O5 --- MW (amu): 150.1
#
#  C5H10BO7
# {'C': 5, 'H': 10, 'B': 1, 'O': 7}
# C5H10BO7 --- MW (amu): 192.9
#
#  C20H24N10O19P4
# {'C': 20, 'H': 24, 'N': 10, 'O': 19, 'P': 4}
# C20H24N10O19P4 --- MW (amu): 832.4
#
#  C5H10O5
# {'C': 5, 'H': 10, 'O': 5}
# C5H10O5 --- MW (amu): 150.1
#
#  C14H13N6O3
# {'C': 14, 'H': 13, 'N': 6, 'O': 3}
# C14H13N6O3 --- MW (amu): 313.3
#
#  C7H9O6
# {'C': 7, 'H': 9, 'O': 6}
# C7H9O6 --- MW (amu): 189.1
#
#  C10H10FeNO6
# {'C': 10, 'H': 10, 'Fe': 1, 'N': 1, 'O': 6}
# C10H10FeNO6 --- MW (amu): 296.0
#
#  C17H32O7P
# {'C': 17, 'H': 32, 'O': 7, 'P': 1}
# C17H32O7P --- MW (amu): 379.4
#
#  C27H33N9O15P2
# {'C': 27, 'H': 33, 'N': 9, 'O': 15, 'P': 2}
# C27H33N9O15P2 --- MW (amu): 785.5
#
#  C10H9O10P
# {'C': 10, 'H': 9, 'O': 10, 'P': 1}
# C10H9O10P --- MW (amu): 320.1
#
#  C5H10O5
# {'C': 5, 'H': 10, 'O': 5}
# C5H10O5 --- MW (amu): 150.1
#
#  C5H7O4
# {'C': 5, 'H': 7, 'O': 4}
# C5H7O4 --- MW (amu): 131.1
#
#  C312H527N6O200P4
# {'C': 312, 'H': 527, 'N': 6, 'O': 200, 'P': 4}
# C312H527N6O200P4 --- MW (amu): 7686
#
#  C5H10BO7
# {'C': 5, 'H': 10, 'B': 1, 'O': 7}
# C5H10BO7 --- MW (amu): 192.9
#
#  C38H70O10P
# {'C': 38, 'H': 70, 'O': 10, 'P': 1}
# C38H70O10P --- MW (amu): 717.9
#
#  C5H11NO2S
# {'C': 5, 'H': 11, 'N': 1, 'O': 2, 'S': 1}
# C5H11NO2S --- MW (amu): 149.2
#
#  C5H5N5O
# {'C': 5, 'H': 5, 'N': 5, 'O': 1}
# C5H5N5O --- MW (amu): 151.1
#
#  C10H12N5O6P
# {'C': 10, 'H': 12, 'N': 5, 'O': 6, 'P': 1}
# C10H12N5O6P --- MW (amu): 329.2
#
#  C2H5O3S
# {'C': 2, 'H': 5, 'O': 3, 'S': 1}
# C2H5O3S --- MW (amu): 109.1
#
#  C10H13N5O9P2
# {'C': 10, 'H': 13, 'N': 5, 'O': 9, 'P': 2}
# C10H13N5O9P2 --- MW (amu): 409.2
#
#  C15H22N2O17P2
# {'C': 15, 'H': 22, 'N': 2, 'O': 17, 'P': 2}
# C15H22N2O17P2 --- MW (amu): 564.3
#
#  C312H527N6O200P4
# {'C': 312, 'H': 527, 'N': 6, 'O': 200, 'P': 4}
# C312H527N6O200P4 --- MW (amu): 7686
#
#  C8H13O2S2
# {'C': 8, 'H': 13, 'O': 2, 'S': 2}
# C8H13O2S2 --- MW (amu): 205.3
#
#  C15H22N2O17P2
# {'C': 15, 'H': 22, 'N': 2, 'O': 17, 'P': 2}
# C15H22N2O17P2 --- MW (amu): 564.3
#
#  C10H12N5O6P
# {'C': 10, 'H': 12, 'N': 5, 'O': 6, 'P': 1}
# C10H12N5O6P --- MW (amu): 329.2
#
#  C5H5O3
# {'C': 5, 'H': 5, 'O': 3}
# C5H5O3 --- MW (amu): 113.1
#
#  C5H11NO2S
# {'C': 5, 'H': 11, 'N': 1, 'O': 2, 'S': 1}
# C5H11NO2S --- MW (amu): 149.2
#
#  C10H10FeNO6
# {'C': 10, 'H': 10, 'Fe': 1, 'N': 1, 'O': 6}
# C10H10FeNO6 --- MW (amu): 296.0
#
#  C38H70O10P
# {'C': 38, 'H': 70, 'O': 10, 'P': 1}
# C38H70O10P --- MW (amu): 717.9
#
#  C2H4O2
# {'C': 2, 'H': 4, 'O': 2}
# C2H4O2 --- MW (amu): 60.05
#
#  C8H13O2S2
# {'C': 8, 'H': 13, 'O': 2, 'S': 2}
# C8H13O2S2 --- MW (amu): 205.3
#
#  C5H11NO2S
# {'C': 5, 'H': 11, 'N': 1, 'O': 2, 'S': 1}
# C5H11NO2S --- MW (amu): 149.2
#
#  C5H5N5O
# {'C': 5, 'H': 5, 'N': 5, 'O': 1}
# C5H5N5O --- MW (amu): 151.1
#
#  C37H62N7O17P3S
# {'C': 37, 'H': 62, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C37H62N7O17P3S --- MW (amu): 1002
#
#  C15H22N2O17P2
# {'C': 15, 'H': 22, 'N': 2, 'O': 17, 'P': 2}
# C15H22N2O17P2 --- MW (amu): 564.3
#
#  C8H13O2S2
# {'C': 8, 'H': 13, 'O': 2, 'S': 2}
# C8H13O2S2 --- MW (amu): 205.3
#
#  C5H5N5O
# {'C': 5, 'H': 5, 'N': 5, 'O': 1}
# C5H5N5O --- MW (amu): 151.1
#
#  C111H167N21O58
# {'C': 111, 'H': 167, 'N': 21, 'O': 58}
# C111H167N21O58 --- MW (amu): 2724
#
#  C9H7O4
# {'C': 9, 'H': 7, 'O': 4}
# C9H7O4 --- MW (amu): 179.1
#
#  C27H52O5
# {'C': 27, 'H': 52, 'O': 5}
# C27H52O5 --- MW (amu): 456.7
#
#  C14H27O2
# {'C': 14, 'H': 27, 'O': 2}
# C14H27O2 --- MW (amu): 227.4
#
#  C14H27O2
# {'C': 14, 'H': 27, 'O': 2}
# C14H27O2 --- MW (amu): 227.4
#
#  C5H11NO2S
# {'C': 5, 'H': 11, 'N': 1, 'O': 2, 'S': 1}
# C5H11NO2S --- MW (amu): 149.2
#
#  C3H3N2O4
# {'C': 3, 'H': 3, 'N': 2, 'O': 4}
# C3H3N2O4 --- MW (amu): 131.1
#
#  C27H47N2O9PRS
# {'C': 27, 'H': 47, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C27H47N2O9PRS --- MW (amu): 606.7
#
#  C25H38N7O17P3S
# {'C': 25, 'H': 38, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C25H38N7O17P3S --- MW (amu): 833.6
#
#  C7H5O6
# {'C': 7, 'H': 5, 'O': 6}
# C7H5O6 --- MW (amu): 185.1
#
#  *
# {}
#
#  C9H7O3
# {'C': 9, 'H': 7, 'O': 3}
# C9H7O3 --- MW (amu): 163.2
#
#  C5H11NO2S
# {'C': 5, 'H': 11, 'N': 1, 'O': 2, 'S': 1}
# C5H11NO2S --- MW (amu): 149.2
#
#  C9H7O3
# {'C': 9, 'H': 7, 'O': 3}
# C9H7O3 --- MW (amu): 163.2
#
#  C14H27O2
# {'C': 14, 'H': 27, 'O': 2}
# C14H27O2 --- MW (amu): 227.4
#
#  C27H52O5
# {'C': 27, 'H': 52, 'O': 5}
# C27H52O5 --- MW (amu): 456.7
#
#  C9H11O4
# {'C': 9, 'H': 11, 'O': 4}
# C9H11O4 --- MW (amu): 183.2
#
#  C15H19N5O14P2
# {'C': 15, 'H': 19, 'N': 5, 'O': 14, 'P': 2}
# C15H19N5O14P2 --- MW (amu): 555.3
#
#  C2H5O3S
# {'C': 2, 'H': 5, 'O': 3, 'S': 1}
# C2H5O3S --- MW (amu): 109.1
#
#  C11H8O5
# {'C': 11, 'H': 8, 'O': 5}
# C11H8O5 --- MW (amu): 220.2
#
#  C2H5O3S
# {'C': 2, 'H': 5, 'O': 3, 'S': 1}
# C2H5O3S --- MW (amu): 109.1
#
#  C15H19N6O6R
# {'C': 15, 'H': 19, 'N': 6, 'O': 6, 'R': 1}
# C15H19N6O6R --- MW (amu): 379.3
#
#  C43H57N4O12
# {'C': 43, 'H': 57, 'N': 4, 'O': 12}
# C43H57N4O12 --- MW (amu): 821.9
#
#  C10H12N4O10P2
# {'C': 10, 'H': 12, 'N': 4, 'O': 10, 'P': 2}
# C10H12N4O10P2 --- MW (amu): 410.2
#
#  C43H57N4O12
# {'C': 43, 'H': 57, 'N': 4, 'O': 12}
# C43H57N4O12 --- MW (amu): 821.9
#
#  C6H7N2O5P
# {'C': 6, 'H': 7, 'N': 2, 'O': 5, 'P': 1}
# C6H7N2O5P --- MW (amu): 218.1
#
#  C9H7O3
# {'C': 9, 'H': 7, 'O': 3}
# C9H7O3 --- MW (amu): 163.2
#
#  C4H8N2O3
# {'C': 4, 'H': 8, 'N': 2, 'O': 3}
# C4H8N2O3 --- MW (amu): 132.1
#
#  C10H11N4O7P
# {'C': 10, 'H': 11, 'N': 4, 'O': 7, 'P': 1}
# C10H11N4O7P --- MW (amu): 330.2
#
#  *
# {}
#
#  C4H8N2O3
# {'C': 4, 'H': 8, 'N': 2, 'O': 3}
# C4H8N2O3 --- MW (amu): 132.1
#
#  C4H8N2O3
# {'C': 4, 'H': 8, 'N': 2, 'O': 3}
# C4H8N2O3 --- MW (amu): 132.1
#
#  C43H75N3O20P2
# {'C': 43, 'H': 75, 'N': 3, 'O': 20, 'P': 2}
# C43H75N3O20P2 --- MW (amu): 1016
#
#  C5H11NO2S
# {'C': 5, 'H': 11, 'N': 1, 'O': 2, 'S': 1}
# C5H11NO2S --- MW (amu): 149.2
#
#  C25H48N2O8PRS
# {'C': 25, 'H': 48, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C25H48N2O8PRS --- MW (amu): 567.7
#
#  CH6O3Te
# {'C': 1, 'H': 6, 'O': 3, 'Te': 1}
# CH6O3Te --- MW (amu): 193.7
#
#  C25H49N6O8
# {'C': 25, 'H': 49, 'N': 6, 'O': 8}
# C25H49N6O8 --- MW (amu): 561.7
#
#  C34H66O10P
# {'C': 34, 'H': 66, 'O': 10, 'P': 1}
# C34H66O10P --- MW (amu): 665.9
#
#  *
# {}
#
#  C8H13N2O5S
# {'C': 8, 'H': 13, 'N': 2, 'O': 5, 'S': 1}
# C8H13N2O5S --- MW (amu): 249.3
#
#  C12H22O11
# {'C': 12, 'H': 22, 'O': 11}
# C12H22O11 --- MW (amu): 342.3
#
#  C6H5O7
# {'C': 6, 'H': 5, 'O': 7}
# C6H5O7 --- MW (amu): 189.1
#
#  C117H211N2O45P2
# {'C': 117, 'H': 211, 'N': 2, 'O': 45, 'P': 2}
# C117H211N2O45P2 --- MW (amu): 2428
#
#  *
# {}
#
#  C34H66O10P
# {'C': 34, 'H': 66, 'O': 10, 'P': 1}
# C34H66O10P --- MW (amu): 665.9
#
#  C6H5O7
# {'C': 6, 'H': 5, 'O': 7}
# C6H5O7 --- MW (amu): 189.1
#
#  C12H22O11
# {'C': 12, 'H': 22, 'O': 11}
# C12H22O11 --- MW (amu): 342.3
#
#  C6H5O7
# {'C': 6, 'H': 5, 'O': 7}
# C6H5O7 --- MW (amu): 189.1
#
#  C12H22O11
# {'C': 12, 'H': 22, 'O': 11}
# C12H22O11 --- MW (amu): 342.3
#
#  C6H11O7
# {'C': 6, 'H': 11, 'O': 7}
# C6H11O7 --- MW (amu): 195.1
#
#  C3H5O3
# {'C': 3, 'H': 5, 'O': 3}
# C3H5O3 --- MW (amu): 89.07
#
#  C6H11O7
# {'C': 6, 'H': 11, 'O': 7}
# C6H11O7 --- MW (amu): 195.1
#
#  *
# {}
#
#  C23H42N2O9PRS
# {'C': 23, 'H': 42, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C23H42N2O9PRS --- MW (amu): 553.6
#
#  C3H5O3
# {'C': 3, 'H': 5, 'O': 3}
# C3H5O3 --- MW (amu): 89.07
#
#  C9H8NO3
# {'C': 9, 'H': 8, 'N': 1, 'O': 3}
# C9H8NO3 --- MW (amu): 178.2
#
#  C25H49N6O8
# {'C': 25, 'H': 49, 'N': 6, 'O': 8}
# C25H49N6O8 --- MW (amu): 561.7
#
#  C3H5O3
# {'C': 3, 'H': 5, 'O': 3}
# C3H5O3 --- MW (amu): 89.07
#
#  Fe4S4
# {'Fe': 4, 'S': 4}
# Fe4S4 --- MW (amu): 351.6
#
#  C7H6NO2
# {'C': 7, 'H': 6, 'N': 1, 'O': 2}
# C7H6NO2 --- MW (amu): 136.1
#
#  C25H49N6O8
# {'C': 25, 'H': 49, 'N': 6, 'O': 8}
# C25H49N6O8 --- MW (amu): 561.7
#
#  C3H7NO2
# {'C': 3, 'H': 7, 'N': 1, 'O': 2}
# C3H7NO2 --- MW (amu): 89.09
#
#  Cs
# {'Cs': 1}
# Cs --- MW (amu): 132.9
#
#  C10H13N5O5
# {'C': 10, 'H': 13, 'N': 5, 'O': 5}
# C10H13N5O5 --- MW (amu): 283.2
#
#  C10H13N5O14P3
# {'C': 10, 'H': 13, 'N': 5, 'O': 14, 'P': 3}
# C10H13N5O14P3 --- MW (amu): 520.2
#
#  C10H13N5O14P3
# {'C': 10, 'H': 13, 'N': 5, 'O': 14, 'P': 3}
# C10H13N5O14P3 --- MW (amu): 520.2
#
#  C6H14O8P
# {'C': 6, 'H': 14, 'O': 8, 'P': 1}
# C6H14O8P --- MW (amu): 245.1
#
#  C6H14O8P
# {'C': 6, 'H': 14, 'O': 8, 'P': 1}
# C6H14O8P --- MW (amu): 245.1
#
#  C5H9O7P
# {'C': 5, 'H': 9, 'O': 7, 'P': 1}
# C5H9O7P --- MW (amu): 212.1
#
#  C4H7NO3
# {'C': 4, 'H': 7, 'N': 1, 'O': 3}
# C4H7NO3 --- MW (amu): 117.1
#
#  C6H11O7
# {'C': 6, 'H': 11, 'O': 7}
# C6H11O7 --- MW (amu): 195.1
#
#  C81H148O17P2
# {'C': 81, 'H': 148, 'O': 17, 'P': 2}
# C81H148O17P2 --- MW (amu): 1456
#
#  C2H5NO2
# {'C': 2, 'H': 5, 'N': 1, 'O': 2}
# C2H5NO2 --- MW (amu): 75.07
#
#  C6H12O9P
# {'C': 6, 'H': 12, 'O': 9, 'P': 1}
# C6H12O9P --- MW (amu): 259.1
#
#  C24H48O9P
# {'C': 24, 'H': 48, 'O': 9, 'P': 1}
# C24H48O9P --- MW (amu): 511.6
#
#  C48H74O4
# {'C': 48, 'H': 74, 'O': 4}
# C48H74O4 --- MW (amu): 715.1
#
#  C23H39N2O8PRS
# {'C': 23, 'H': 39, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C23H39N2O8PRS --- MW (amu): 534.6
#
#  C2H5NO2
# {'C': 2, 'H': 5, 'N': 1, 'O': 2}
# C2H5NO2 --- MW (amu): 75.07
#
#  C24H48O9P
# {'C': 24, 'H': 48, 'O': 9, 'P': 1}
# C24H48O9P --- MW (amu): 511.6
#
#  *
# {}
#
#  C65H124O17P2
# {'C': 65, 'H': 124, 'O': 17, 'P': 2}
# C65H124O17P2 --- MW (amu): 1240
#
#  *
# {}
#
#  C2H5NO2
# {'C': 2, 'H': 5, 'N': 1, 'O': 2}
# C2H5NO2 --- MW (amu): 75.07
#
#  C6H3O6
# {'C': 6, 'H': 3, 'O': 6}
# C6H3O6 --- MW (amu): 171.1
#
#  C10H13N5O14P3
# {'C': 10, 'H': 13, 'N': 5, 'O': 14, 'P': 3}
# C10H13N5O14P3 --- MW (amu): 520.2
#
#  C15H29O7P
# {'C': 15, 'H': 29, 'O': 7, 'P': 1}
# C15H29O7P --- MW (amu): 352.4
#
#  HO4P
# {'H': 1, 'O': 4, 'P': 1}
# HO4P --- MW (amu): 95.98
#
#  C6H8O8
# {'C': 6, 'H': 8, 'O': 8}
# C6H8O8 --- MW (amu): 208.1
#
#  C6H14O6
# {'C': 6, 'H': 14, 'O': 6}
# C6H14O6 --- MW (amu): 182.2
#
#  C17H22N4O6
# {'C': 17, 'H': 22, 'N': 4, 'O': 6}
# C17H22N4O6 --- MW (amu): 378.4
#
#  *
# {}
#
#  HO4P
# {'H': 1, 'O': 4, 'P': 1}
# HO4P --- MW (amu): 95.98
#
#  C6H15N2O2
# {'C': 6, 'H': 15, 'N': 2, 'O': 2}
# C6H15N2O2 --- MW (amu): 147.2
#
#  C8H12N2O5P
# {'C': 8, 'H': 12, 'N': 2, 'O': 5, 'P': 1}
# C8H12N2O5P --- MW (amu): 247.2
#
#  C42H78O13P2
# {'C': 42, 'H': 78, 'O': 13, 'P': 2}
# C42H78O13P2 --- MW (amu): 853.0
#
#  C10H13N5O5
# {'C': 10, 'H': 13, 'N': 5, 'O': 5}
# C10H13N5O5 --- MW (amu): 283.2
#
#  C6H15N2O2
# {'C': 6, 'H': 15, 'N': 2, 'O': 2}
# C6H15N2O2 --- MW (amu): 147.2
#
#  C3H5N2O4
# {'C': 3, 'H': 5, 'N': 2, 'O': 4}
# C3H5N2O4 --- MW (amu): 133.1
#
#  C17H34O7P
# {'C': 17, 'H': 34, 'O': 7, 'P': 1}
# C17H34O7P --- MW (amu): 381.4
#
#  C10H13N5O5
# {'C': 10, 'H': 13, 'N': 5, 'O': 5}
# C10H13N5O5 --- MW (amu): 283.2
#
#  C9H8N2O2
# {'C': 9, 'H': 8, 'N': 2, 'O': 2}
# C9H8N2O2 --- MW (amu): 176.2
#
#  C15H29O7P
# {'C': 15, 'H': 29, 'O': 7, 'P': 1}
# C15H29O7P --- MW (amu): 352.4
#
#  C8H12NO2
# {'C': 8, 'H': 12, 'N': 1, 'O': 2}
# C8H12NO2 --- MW (amu): 154.2
#
#  HO4P
# {'H': 1, 'O': 4, 'P': 1}
# HO4P --- MW (amu): 95.98
#
#  C6H8O8
# {'C': 6, 'H': 8, 'O': 8}
# C6H8O8 --- MW (amu): 208.1
#
#  C42H78O13P2
# {'C': 42, 'H': 78, 'O': 13, 'P': 2}
# C42H78O13P2 --- MW (amu): 853.0
#
#  C6H8O8
# {'C': 6, 'H': 8, 'O': 8}
# C6H8O8 --- MW (amu): 208.1
#
#  C8H12NO2
# {'C': 8, 'H': 12, 'N': 1, 'O': 2}
# C8H12NO2 --- MW (amu): 154.2
#
#  *
# {}
#
#  C3H8O2
# {'C': 3, 'H': 8, 'O': 2}
# C3H8O2 --- MW (amu): 76.09
#
#  Ca
# {'Ca': 1}
# Ca --- MW (amu): 40.08
#
#  C44H79N3O15P2
# {'C': 44, 'H': 79, 'N': 3, 'O': 15, 'P': 2}
# C44H79N3O15P2 --- MW (amu): 952.1
#
#  C3H8O2
# {'C': 3, 'H': 8, 'O': 2}
# C3H8O2 --- MW (amu): 76.09
#
#  C9H17NO3
# {'C': 9, 'H': 17, 'N': 1, 'O': 3}
# C9H17NO3 --- MW (amu): 187.2
#
#  C30H52O26
# {'C': 30, 'H': 52, 'O': 26}
# C30H52O26 --- MW (amu): 828.7
#
#  C27H42N7O18P3S
# {'C': 27, 'H': 42, 'N': 7, 'O': 18, 'P': 3, 'S': 1}
# C27H42N7O18P3S --- MW (amu): 877.6
#
#  C23H41N2O8PRS
# {'C': 23, 'H': 41, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C23H41N2O8PRS --- MW (amu): 536.6
#
#  Ca
# {'Ca': 1}
# Ca --- MW (amu): 40.08
#
#  Co
# {'Co': 1}
# Co --- MW (amu): 58.93
#
#  C17H34O7P
# {'C': 17, 'H': 34, 'O': 7, 'P': 1}
# C17H34O7P --- MW (amu): 381.4
#
#  Co
# {'Co': 1}
# Co --- MW (amu): 58.93
#
#  C8H9NO3
# {'C': 8, 'H': 9, 'N': 1, 'O': 3}
# C8H9NO3 --- MW (amu): 167.2
#
#  Co
# {'Co': 1}
# Co --- MW (amu): 58.93
#
#  Ca
# {'Ca': 1}
# Ca --- MW (amu): 40.08
#
#  C3H6O2
# {'C': 3, 'H': 6, 'O': 2}
# C3H6O2 --- MW (amu): 74.08
#
#  C3H8O2
# {'C': 3, 'H': 8, 'O': 2}
# C3H8O2 --- MW (amu): 76.09
#
#  C6H12O5
# {'C': 6, 'H': 12, 'O': 5}
# C6H12O5 --- MW (amu): 164.2
#
#  C5H9O4
# {'C': 5, 'H': 9, 'O': 4}
# C5H9O4 --- MW (amu): 133.1
#
#  C23H26N3O7
# {'C': 23, 'H': 26, 'N': 3, 'O': 7}
# C23H26N3O7 --- MW (amu): 456.5
#
#  C17H30N2O9PRS
# {'C': 17, 'H': 30, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C17H30N2O9PRS --- MW (amu): 469.5
#
#  C23H26N3O7
# {'C': 23, 'H': 26, 'N': 3, 'O': 7}
# C23H26N3O7 --- MW (amu): 456.5
#
#  C40H36N4O16
# {'C': 40, 'H': 36, 'N': 4, 'O': 16}
# C40H36N4O16 --- MW (amu): 828.7
#
#  C6H12O5
# {'C': 6, 'H': 12, 'O': 5}
# C6H12O5 --- MW (amu): 164.2
#
#  C8H9NO3
# {'C': 8, 'H': 9, 'N': 1, 'O': 3}
# C8H9NO3 --- MW (amu): 167.2
#
#  C8H9NO3
# {'C': 8, 'H': 9, 'N': 1, 'O': 3}
# C8H9NO3 --- MW (amu): 167.2
#
#  C21H28N7O18P3
# {'C': 21, 'H': 28, 'N': 7, 'O': 18, 'P': 3}
# C21H28N7O18P3 --- MW (amu): 759.4
#
#  C30H52O26
# {'C': 30, 'H': 52, 'O': 26}
# C30H52O26 --- MW (amu): 828.7
#
#  C4H2O5
# {'C': 4, 'H': 2, 'O': 5}
# C4H2O5 --- MW (amu): 130.1
#
#  C272H451N14O160P4
# {'C': 272, 'H': 451, 'N': 14, 'O': 160, 'P': 4}
# C272H451N14O160P4 --- MW (amu): 6601
#
#  C8H7O4
# {'C': 8, 'H': 7, 'O': 4}
# C8H7O4 --- MW (amu): 167.1
#
#  C272H451N14O160P4
# {'C': 272, 'H': 451, 'N': 14, 'O': 160, 'P': 4}
# C272H451N14O160P4 --- MW (amu): 6601
#
#  C30H52O26
# {'C': 30, 'H': 52, 'O': 26}
# C30H52O26 --- MW (amu): 828.7
#
#  C7H13O10P
# {'C': 7, 'H': 13, 'O': 10, 'P': 1}
# C7H13O10P --- MW (amu): 288.1
#
#  C6H12O5
# {'C': 6, 'H': 12, 'O': 5}
# C6H12O5 --- MW (amu): 164.2
#
#  C4H4O6
# {'C': 4, 'H': 4, 'O': 6}
# C4H4O6 --- MW (amu): 148.1
#
#  C6H5O7
# {'C': 6, 'H': 5, 'O': 7}
# C6H5O7 --- MW (amu): 189.1
#
#  C34H52N6O19
# {'C': 34, 'H': 52, 'N': 6, 'O': 19}
# C34H52N6O19 --- MW (amu): 848.8
#
#  C17H33O7P
# {'C': 17, 'H': 33, 'O': 7, 'P': 1}
# C17H33O7P --- MW (amu): 380.4
#
#  C11H18NO11P
# {'C': 11, 'H': 18, 'N': 1, 'O': 11, 'P': 1}
# C11H18NO11P --- MW (amu): 371.2
#
#  C7H22N3
# {'C': 7, 'H': 22, 'N': 3}
# C7H22N3 --- MW (amu): 148.3
#
#  C7H22N3
# {'C': 7, 'H': 22, 'N': 3}
# C7H22N3 --- MW (amu): 148.3
#
#  C34H52N6O19
# {'C': 34, 'H': 52, 'N': 6, 'O': 19}
# C34H52N6O19 --- MW (amu): 848.8
#
#  C7H22N3
# {'C': 7, 'H': 22, 'N': 3}
# C7H22N3 --- MW (amu): 148.3
#
#  C7H7O4
# {'C': 7, 'H': 7, 'O': 4}
# C7H7O4 --- MW (amu): 155.1
#
#  C6H15N2O2
# {'C': 6, 'H': 15, 'N': 2, 'O': 2}
# C6H15N2O2 --- MW (amu): 147.2
#
#  C43H81NO8P
# {'C': 43, 'H': 81, 'N': 1, 'O': 8, 'P': 1}
# C43H81NO8P --- MW (amu): 771.1
#
#  C40H67N3O15P2
# {'C': 40, 'H': 67, 'N': 3, 'O': 15, 'P': 2}
# C40H67N3O15P2 --- MW (amu): 891.9
#
#  C20H38O9P
# {'C': 20, 'H': 38, 'O': 9, 'P': 1}
# C20H38O9P --- MW (amu): 453.5
#
#  C3H3O4
# {'C': 3, 'H': 3, 'O': 4}
# C3H3O4 --- MW (amu): 103.1
#
#  CH4O
# {'C': 1, 'H': 4, 'O': 1}
# CH4O --- MW (amu): 32.04
#
#  C4H4O6
# {'C': 4, 'H': 4, 'O': 6}
# C4H4O6 --- MW (amu): 148.1
#
#  C19H36N2O9PRS
# {'C': 19, 'H': 36, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C19H36N2O9PRS --- MW (amu): 499.5
#
#  C10H11N5O7P
# {'C': 10, 'H': 11, 'N': 5, 'O': 7, 'P': 1}
# C10H11N5O7P --- MW (amu): 344.2
#
#  CH4O
# {'C': 1, 'H': 4, 'O': 1}
# CH4O --- MW (amu): 32.04
#
#  *
# {}
#
#  CH4O
# {'C': 1, 'H': 4, 'O': 1}
# CH4O --- MW (amu): 32.04
#
#  C4H4O6
# {'C': 4, 'H': 4, 'O': 6}
# C4H4O6 --- MW (amu): 148.1
#
#  C10H11N5O7P
# {'C': 10, 'H': 11, 'N': 5, 'O': 7, 'P': 1}
# C10H11N5O7P --- MW (amu): 344.2
#
#  C39H73NO8P
# {'C': 39, 'H': 73, 'N': 1, 'O': 8, 'P': 1}
# C39H73NO8P --- MW (amu): 715.0
#
#  C9H13N5O4
# {'C': 9, 'H': 13, 'N': 5, 'O': 4}
# C9H13N5O4 --- MW (amu): 255.2
#
#  C9H13N5O13P3
# {'C': 9, 'H': 13, 'N': 5, 'O': 13, 'P': 3}
# C9H13N5O13P3 --- MW (amu): 492.1
#
#  C10H12N4O6
# {'C': 10, 'H': 12, 'N': 4, 'O': 6}
# C10H12N4O6 --- MW (amu): 284.2
#
#  C25H43N2O8PRS
# {'C': 25, 'H': 43, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C25H43N2O8PRS --- MW (amu): 562.7
#
#  C10H12N4O6
# {'C': 10, 'H': 12, 'N': 4, 'O': 6}
# C10H12N4O6 --- MW (amu): 284.2
#
#  C10H12N4O6
# {'C': 10, 'H': 12, 'N': 4, 'O': 6}
# C10H12N4O6 --- MW (amu): 284.2
#
#  C7H13O10P
# {'C': 7, 'H': 13, 'O': 10, 'P': 1}
# C7H13O10P --- MW (amu): 288.1
#
#  C8H12NO6
# {'C': 8, 'H': 12, 'N': 1, 'O': 6}
# C8H12NO6 --- MW (amu): 218.2
#
#  C20H38O9P
# {'C': 20, 'H': 38, 'O': 9, 'P': 1}
# C20H38O9P --- MW (amu): 453.5
#
#  C151H261N2O79P4
# {'C': 151, 'H': 261, 'N': 2, 'O': 79, 'P': 4}
# C151H261N2O79P4 --- MW (amu): 3493
#
#  C27H42FeN9O12
# {'C': 27, 'H': 42, 'Fe': 1, 'N': 9, 'O': 12}
# C27H42FeN9O12 --- MW (amu): 740.5
#
#  C9H12N3O8P
# {'C': 9, 'H': 12, 'N': 3, 'O': 8, 'P': 1}
# C9H12N3O8P --- MW (amu): 321.2
#
#  K
# {'K': 1}
# K --- MW (amu): 39.10
#
#  C27H42FeN9O12
# {'C': 27, 'H': 42, 'Fe': 1, 'N': 9, 'O': 12}
# C27H42FeN9O12 --- MW (amu): 740.5
#
#  C27H42FeN9O12
# {'C': 27, 'H': 42, 'Fe': 1, 'N': 9, 'O': 12}
# C27H42FeN9O12 --- MW (amu): 740.5
#
#  C31H48N7O17P3S
# {'C': 31, 'H': 48, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C31H48N7O17P3S --- MW (amu): 915.7
#
#  C48H74O3
# {'C': 48, 'H': 74, 'O': 3}
# C48H74O3 --- MW (amu): 699.1
#
#  C6H13NO2
# {'C': 6, 'H': 13, 'N': 1, 'O': 2}
# C6H13NO2 --- MW (amu): 131.2
#
#  C151H234N12O67P2
# {'C': 151, 'H': 234, 'N': 12, 'O': 67, 'P': 2}
# C151H234N12O67P2 --- MW (amu): 3351
#
#  C23H46NO7P
# {'C': 23, 'H': 46, 'N': 1, 'O': 7, 'P': 1}
# C23H46NO7P --- MW (amu): 479.6
#
#  C9H12N3O8P
# {'C': 9, 'H': 12, 'N': 3, 'O': 8, 'P': 1}
# C9H12N3O8P --- MW (amu): 321.2
#
#  C6H13NO2
# {'C': 6, 'H': 13, 'N': 1, 'O': 2}
# C6H13NO2 --- MW (amu): 131.2
#
#  C6H9NO2R2S2
# {'C': 6, 'H': 9, 'N': 1, 'O': 2, 'R': 2, 'S': 2}
# C6H9NO2R2S2 --- MW (amu): 129.1
#
#  C6H11O4
# {'C': 6, 'H': 11, 'O': 4}
# C6H11O4 --- MW (amu): 147.1
#
#  C6H13NO2
# {'C': 6, 'H': 13, 'N': 1, 'O': 2}
# C6H13NO2 --- MW (amu): 131.2
#
#  H2
# {'H': 2}
# H2 --- MW (amu): 2.016
#
#  C6H14NO5
# {'C': 6, 'H': 14, 'N': 1, 'O': 5}
# C6H14NO5 --- MW (amu): 180.2
#
#  C6H14NO5
# {'C': 6, 'H': 14, 'N': 1, 'O': 5}
# C6H14NO5 --- MW (amu): 180.2
#
#  C13H20N3O8S
# {'C': 13, 'H': 20, 'N': 3, 'O': 8, 'S': 1}
# C13H20N3O8S --- MW (amu): 378.4
#
#  C10H14N2O14P3
# {'C': 10, 'H': 14, 'N': 2, 'O': 14, 'P': 3}
# C10H14N2O14P3 --- MW (amu): 479.1
#
#  C9H15O12P
# {'C': 9, 'H': 15, 'O': 12, 'P': 1}
# C9H15O12P --- MW (amu): 346.2
#
#  H2
# {'H': 2}
# H2 --- MW (amu): 2.016
#
#  H2
# {'H': 2}
# H2 --- MW (amu): 2.016
#
#  C62H91CoN13O14P
# {'C': 62, 'H': 91, 'Co': 1, 'N': 13, 'O': 14, 'P': 1}
# C62H91CoN13O14P --- MW (amu): 1332
#
#  K
# {'K': 1}
# K --- MW (amu): 39.10
#
#  C39H72O5
# {'C': 39, 'H': 72, 'O': 5}
# C39H72O5 --- MW (amu): 621.0
#
#  C6H14NO5
# {'C': 6, 'H': 14, 'N': 1, 'O': 5}
# C6H14NO5 --- MW (amu): 180.2
#
#  K
# {'K': 1}
# K --- MW (amu): 39.10
#
#  C6H14O6
# {'C': 6, 'H': 14, 'O': 6}
# C6H14O6 --- MW (amu): 182.2
#
#  C39H72O5
# {'C': 39, 'H': 72, 'O': 5}
# C39H72O5 --- MW (amu): 621.0
#
#  C16H24N2O16P2
# {'C': 16, 'H': 24, 'N': 2, 'O': 16, 'P': 2}
# C16H24N2O16P2 --- MW (amu): 562.3
#
#  C7H10O5
# {'C': 7, 'H': 10, 'O': 5}
# C7H10O5 --- MW (amu): 174.2
#
#  C62H91CoN13O14P
# {'C': 62, 'H': 91, 'Co': 1, 'N': 13, 'O': 14, 'P': 1}
# C62H91CoN13O14P --- MW (amu): 1332
#
#  C6H9O3
# {'C': 6, 'H': 9, 'O': 3}
# C6H9O3 --- MW (amu): 129.1
#
#  *
# {}
#
#  C62H91CoN13O14P
# {'C': 62, 'H': 91, 'Co': 1, 'N': 13, 'O': 14, 'P': 1}
# C62H91CoN13O14P --- MW (amu): 1332
#
#  C21H40N2O8PRS
# {'C': 21, 'H': 40, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C21H40N2O8PRS --- MW (amu): 511.6
#
#  C9H12N2O6
# {'C': 9, 'H': 12, 'N': 2, 'O': 6}
# C9H12N2O6 --- MW (amu): 244.2
#
#  C23H41N2O9PRS
# {'C': 23, 'H': 41, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C23H41N2O9PRS --- MW (amu): 552.6
#
#  C5H9O8P
# {'C': 5, 'H': 9, 'O': 8, 'P': 1}
# C5H9O8P --- MW (amu): 228.1
#
#  C6H12O9P
# {'C': 6, 'H': 12, 'O': 9, 'P': 1}
# C6H12O9P --- MW (amu): 259.1
#
#  C21H40O7P
# {'C': 21, 'H': 40, 'O': 7, 'P': 1}
# C21H40O7P --- MW (amu): 435.5
#
#  C37H60N7O17P3S
# {'C': 37, 'H': 60, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C37H60N7O17P3S --- MW (amu): 999.9
#
#  *
# {}
#
#  C6H13NO8P
# {'C': 6, 'H': 13, 'N': 1, 'O': 8, 'P': 1}
# C6H13NO8P --- MW (amu): 258.1
#
#  C9H12N2O6
# {'C': 9, 'H': 12, 'N': 2, 'O': 6}
# C9H12N2O6 --- MW (amu): 244.2
#
#  C48H83N3O15P2
# {'C': 48, 'H': 83, 'N': 3, 'O': 15, 'P': 2}
# C48H83N3O15P2 --- MW (amu): 1004
#
#  C10H8O6
# {'C': 10, 'H': 8, 'O': 6}
# C10H8O6 --- MW (amu): 224.2
#
#  C4H8NO6P
# {'C': 4, 'H': 8, 'N': 1, 'O': 6, 'P': 1}
# C4H8NO6P --- MW (amu): 197.1
#
#  C25H46N2O9PRS
# {'C': 25, 'H': 46, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C25H46N2O9PRS --- MW (amu): 581.7
#
#  C4H9NO3
# {'C': 4, 'H': 9, 'N': 1, 'O': 3}
# C4H9NO3 --- MW (amu): 119.1
#
#  C4H6NO4
# {'C': 4, 'H': 6, 'N': 1, 'O': 4}
# C4H6NO4 --- MW (amu): 132.1
#
#  C4H6NO4
# {'C': 4, 'H': 6, 'N': 1, 'O': 4}
# C4H6NO4 --- MW (amu): 132.1
#
#  C9H12N2O6
# {'C': 9, 'H': 12, 'N': 2, 'O': 6}
# C9H12N2O6 --- MW (amu): 244.2
#
#  C6H13NO8P
# {'C': 6, 'H': 13, 'N': 1, 'O': 8, 'P': 1}
# C6H13NO8P --- MW (amu): 258.1
#
#  C8H15NO6
# {'C': 8, 'H': 15, 'N': 1, 'O': 6}
# C8H15NO6 --- MW (amu): 221.2
#
#  C19H36N2O8PRS
# {'C': 19, 'H': 36, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C19H36N2O8PRS --- MW (amu): 483.5
#
#  HAsO4
# {'H': 1, 'As': 1, 'O': 4}
# HAsO4 --- MW (amu): 139.9
#
#  *
# {}
#
#  C4H9NO3
# {'C': 4, 'H': 9, 'N': 1, 'O': 3}
# C4H9NO3 --- MW (amu): 119.1
#
#  C4H9NO3
# {'C': 4, 'H': 9, 'N': 1, 'O': 3}
# C4H9NO3 --- MW (amu): 119.1
#
#  C31H48N7O18P3S
# {'C': 31, 'H': 48, 'N': 7, 'O': 18, 'P': 3, 'S': 1}
# C31H48N7O18P3S --- MW (amu): 931.7
#
#  C8H15NO6
# {'C': 8, 'H': 15, 'N': 1, 'O': 6}
# C8H15NO6 --- MW (amu): 221.2
#
#  C4H6NO4
# {'C': 4, 'H': 6, 'N': 1, 'O': 4}
# C4H6NO4 --- MW (amu): 132.1
#
#  C68H102N12O37
# {'C': 68, 'H': 102, 'N': 12, 'O': 37}
# C68H102N12O37 --- MW (amu): 1680
#
#  C3H8O3
# {'C': 3, 'H': 8, 'O': 3}
# C3H8O3 --- MW (amu): 92.09
#
#  C5H10N2O3S
# {'C': 5, 'H': 10, 'N': 2, 'O': 3, 'S': 1}
# C5H10N2O3S --- MW (amu): 178.2
#
#  C8H15NO6
# {'C': 8, 'H': 15, 'N': 1, 'O': 6}
# C8H15NO6 --- MW (amu): 221.2
#
#  C4H4O4
# {'C': 4, 'H': 4, 'O': 4}
# C4H4O4 --- MW (amu): 116.1
#
#  C4H4O4
# {'C': 4, 'H': 4, 'O': 4}
# C4H4O4 --- MW (amu): 116.1
#
#  C3H8O3
# {'C': 3, 'H': 8, 'O': 3}
# C3H8O3 --- MW (amu): 92.09
#
#  C5H10N2O3S
# {'C': 5, 'H': 10, 'N': 2, 'O': 3, 'S': 1}
# C5H10N2O3S --- MW (amu): 178.2
#
#  C3H8O3
# {'C': 3, 'H': 8, 'O': 3}
# C3H8O3 --- MW (amu): 92.09
#
#  C6H13NO8P
# {'C': 6, 'H': 13, 'N': 1, 'O': 8, 'P': 1}
# C6H13NO8P --- MW (amu): 258.1
#
#  C5H10N2O3S
# {'C': 5, 'H': 10, 'N': 2, 'O': 3, 'S': 1}
# C5H10N2O3S --- MW (amu): 178.2
#
#  C47H72O2
# {'C': 47, 'H': 72, 'O': 2}
# C47H72O2 --- MW (amu): 669.1
#
#  C6H6O9P
# {'C': 6, 'H': 6, 'O': 9, 'P': 1}
# C6H6O9P --- MW (amu): 253.1
#
#  C6H12N3O
# {'C': 6, 'H': 12, 'N': 3, 'O': 1}
# C6H12N3O --- MW (amu): 142.2
#
#  H2O3P
# {'H': 2, 'O': 3, 'P': 1}
# H2O3P --- MW (amu): 80.99
#
#  C4H4O4
# {'C': 4, 'H': 4, 'O': 4}
# C4H4O4 --- MW (amu): 116.1
#
#  C71H107N13O38
# {'C': 71, 'H': 107, 'N': 13, 'O': 38}
# C71H107N13O38 --- MW (amu): 1751
#
#  C77H117N15O40
# {'C': 77, 'H': 117, 'N': 15, 'O': 40}
# C77H117N15O40 --- MW (amu): 1893
#
#  C39H65N7O18P3S
# {'C': 39, 'H': 65, 'N': 7, 'O': 18, 'P': 3, 'S': 1}
# C39H65N7O18P3S --- MW (amu): 1045
#
#  H2O3P
# {'H': 2, 'O': 3, 'P': 1}
# H2O3P --- MW (amu): 80.99
#
#  C58H87CoN16O11
# {'C': 58, 'H': 87, 'Co': 1, 'N': 16, 'O': 11}
# C58H87CoN16O11 --- MW (amu): 1243
#
#  C5H10O9P2
# {'C': 5, 'H': 10, 'O': 9, 'P': 2}
# C5H10O9P2 --- MW (amu): 276.1
#
#  C24H48O9P
# {'C': 24, 'H': 48, 'O': 9, 'P': 1}
# C24H48O9P --- MW (amu): 511.6
#
#  C65H116O17P2
# {'C': 65, 'H': 116, 'O': 17, 'P': 2}
# C65H116O17P2 --- MW (amu): 1232
#
#  C4H4N2O2
# {'C': 4, 'H': 4, 'N': 2, 'O': 2}
# C4H4N2O2 --- MW (amu): 112.1
#
#  *
# {}
#
#  C9H12N2O5
# {'C': 9, 'H': 12, 'N': 2, 'O': 5}
# C9H12N2O5 --- MW (amu): 228.2
#
#  C11H18NO9
# {'C': 11, 'H': 18, 'N': 1, 'O': 9}
# C11H18NO9 --- MW (amu): 308.3
#
#  C19H22MoN8O15P2S2
# {'C': 19, 'H': 22, 'Mo': 1, 'N': 8, 'O': 15, 'P': 2, 'S': 2}
# C19H22MoN8O15P2S2 --- MW (amu): 824.5
#
#  C51H74O2
# {'C': 51, 'H': 74, 'O': 2}
# C51H74O2 --- MW (amu): 719.1
#
#  C11H18NO9
# {'C': 11, 'H': 18, 'N': 1, 'O': 9}
# C11H18NO9 --- MW (amu): 308.3
#
#  C6H9O7
# {'C': 6, 'H': 9, 'O': 7}
# C6H9O7 --- MW (amu): 193.1
#
#  C11H18NO9
# {'C': 11, 'H': 18, 'N': 1, 'O': 9}
# C11H18NO9 --- MW (amu): 308.3
#
#  C42H36FeN4O16
# {'C': 42, 'H': 36, 'Fe': 1, 'N': 4, 'O': 16}
# C42H36FeN4O16 --- MW (amu): 908.6
#
#  H2O3Te
# {'H': 2, 'O': 3, 'Te': 1}
# H2O3Te --- MW (amu): 177.6
#
#  C20H24N10O21P4
# {'C': 20, 'H': 24, 'N': 10, 'O': 21, 'P': 4}
# C20H24N10O21P4 --- MW (amu): 864.4
#
#  C9H12N2O11P2
# {'C': 9, 'H': 12, 'N': 2, 'O': 11, 'P': 2}
# C9H12N2O11P2 --- MW (amu): 386.1
#
#  *
# {}
#
#  C7H12NO3S
# {'C': 7, 'H': 12, 'N': 1, 'O': 3, 'S': 1}
# C7H12NO3S --- MW (amu): 190.2
#
#  C9H12N2O5
# {'C': 9, 'H': 12, 'N': 2, 'O': 5}
# C9H12N2O5 --- MW (amu): 228.2
#
#  C4H4N2O2
# {'C': 4, 'H': 4, 'N': 2, 'O': 2}
# C4H4N2O2 --- MW (amu): 112.1
#
#  C14H20N6O5S
# {'C': 14, 'H': 20, 'N': 6, 'O': 5, 'S': 1}
# C14H20N6O5S --- MW (amu): 384.4
#
#  C9H12N2O5
# {'C': 9, 'H': 12, 'N': 2, 'O': 5}
# C9H12N2O5 --- MW (amu): 228.2
#
#  C48H86O11P
# {'C': 48, 'H': 86, 'O': 11, 'P': 1}
# C48H86O11P --- MW (amu): 870.2
#
#  C4H4N2O2
# {'C': 4, 'H': 4, 'N': 2, 'O': 2}
# C4H4N2O2 --- MW (amu): 112.1
#
#  Zn
# {'Zn': 1}
# Zn --- MW (amu): 65.38
#
#  C5H9O8P
# {'C': 5, 'H': 9, 'O': 8, 'P': 1}
# C5H9O8P --- MW (amu): 228.1
#
#  C6H7O6
# {'C': 6, 'H': 7, 'O': 6}
# C6H7O6 --- MW (amu): 175.1
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  Zn
# {'Zn': 1}
# Zn --- MW (amu): 65.38
#
#  C8H12NO
# {'C': 8, 'H': 12, 'N': 1, 'O': 1}
# C8H12NO --- MW (amu): 138.2
#
#  *
# {}
#
#  Zn
# {'Zn': 1}
# Zn --- MW (amu): 65.38
#
#  C4H7O3
# {'C': 4, 'H': 7, 'O': 3}
# C4H7O3 --- MW (amu): 103.1
#
#  C7H13O10P
# {'C': 7, 'H': 13, 'O': 10, 'P': 1}
# C7H13O10P --- MW (amu): 288.1
#
#  C11H16N2O7
# {'C': 11, 'H': 16, 'N': 2, 'O': 7}
# C11H16N2O7 --- MW (amu): 288.3
#
#  C5H14NO
# {'C': 5, 'H': 14, 'N': 1, 'O': 1}
# C5H14NO --- MW (amu): 104.2
#
#  C21H37N2O8PRS
# {'C': 21, 'H': 37, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C21H37N2O8PRS --- MW (amu): 508.6
#
#  C3H8N2O2
# {'C': 3, 'H': 8, 'N': 2, 'O': 2}
# C3H8N2O2 --- MW (amu): 104.1
#
#  C3H8N2O2
# {'C': 3, 'H': 8, 'N': 2, 'O': 2}
# C3H8N2O2 --- MW (amu): 104.1
#
#  *
# {}
#
#  C23H41N2O8PRS
# {'C': 23, 'H': 41, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C23H41N2O8PRS --- MW (amu): 536.6
#
#  C4H3NO4
# {'C': 4, 'H': 3, 'N': 1, 'O': 4}
# C4H3NO4 --- MW (amu): 129.1
#
#  C20H28N3O19P2
# {'C': 20, 'H': 28, 'N': 3, 'O': 19, 'P': 2}
# C20H28N3O19P2 --- MW (amu): 676.4
#
#  O2
# {'O': 2}
# O2 --- MW (amu): 32.00
#
#  C3H8N2O2
# {'C': 3, 'H': 8, 'N': 2, 'O': 2}
# C3H8N2O2 --- MW (amu): 104.1
#
#  C20H20N7O6
# {'C': 20, 'H': 20, 'N': 7, 'O': 6}
# C20H20N7O6 --- MW (amu): 454.4
#
#  O2
# {'O': 2}
# O2 --- MW (amu): 32.00
#
#  C21H40O7P
# {'C': 21, 'H': 40, 'O': 7, 'P': 1}
# C21H40O7P --- MW (amu): 435.5
#
#  O2
# {'O': 2}
# O2 --- MW (amu): 32.00
#
#  C5H14NO
# {'C': 5, 'H': 14, 'N': 1, 'O': 1}
# C5H14NO --- MW (amu): 104.2
#
#  C5H14NO
# {'C': 5, 'H': 14, 'N': 1, 'O': 1}
# C5H14NO --- MW (amu): 104.2
#
#  C16H23N5O16P2
# {'C': 16, 'H': 23, 'N': 5, 'O': 16, 'P': 2}
# C16H23N5O16P2 --- MW (amu): 603.3
#
#  C40H38N4O17
# {'C': 40, 'H': 38, 'N': 4, 'O': 17}
# C40H38N4O17 --- MW (amu): 846.7
#
#  C30H52O26
# {'C': 30, 'H': 52, 'O': 26}
# C30H52O26 --- MW (amu): 828.7
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C7H14N2O4
# {'C': 7, 'H': 14, 'N': 2, 'O': 4}
# C7H14N2O4 --- MW (amu): 190.2
#
#  C2H6OS
# {'C': 2, 'H': 6, 'O': 1, 'S': 1}
# C2H6OS --- MW (amu): 78.13
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C13H17N4O6
# {'C': 13, 'H': 17, 'N': 4, 'O': 6}
# C13H17N4O6 --- MW (amu): 325.3
#
#  C11H16N3O7S
# {'C': 11, 'H': 16, 'N': 3, 'O': 7, 'S': 1}
# C11H16N3O7S --- MW (amu): 334.3
#
#  C11H21N2O7PS
# {'C': 11, 'H': 21, 'N': 2, 'O': 7, 'P': 1, 'S': 1}
# C11H21N2O7PS --- MW (amu): 356.3
#
#  C3H6O2
# {'C': 3, 'H': 6, 'O': 2}
# C3H6O2 --- MW (amu): 74.08
#
#  C6H7NO2R2S2
# {'C': 6, 'H': 7, 'N': 1, 'O': 2, 'R': 2, 'S': 2}
# C6H7NO2R2S2 --- MW (amu): 127.1
#
#  *
# {}
#
#  CHN
# {'C': 1, 'H': 1, 'N': 1}
# CHN --- MW (amu): 27.03
#
#  C10H12N5O10PS
# {'C': 10, 'H': 12, 'N': 5, 'O': 10, 'P': 1, 'S': 1}
# C10H12N5O10PS --- MW (amu): 425.3
#
#  C10H13N2O4
# {'C': 10, 'H': 13, 'N': 2, 'O': 4}
# C10H13N2O4 --- MW (amu): 225.2
#
#  C23H34N7O17P3S
# {'C': 23, 'H': 34, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C23H34N7O17P3S --- MW (amu): 805.5
#
#  C35H64O5
# {'C': 35, 'H': 64, 'O': 5}
# C35H64O5 --- MW (amu): 564.9
#
#  *
# {}
#
#  *
# {}
#
#  *
# {}
#
#  C9H15N4O9P
# {'C': 9, 'H': 15, 'N': 4, 'O': 9, 'P': 1}
# C9H15N4O9P --- MW (amu): 354.2
#
#  C6H12O6
# {'C': 6, 'H': 12, 'O': 6}
# C6H12O6 --- MW (amu): 180.2
#
#  C6H12O6
# {'C': 6, 'H': 12, 'O': 6}
# C6H12O6 --- MW (amu): 180.2
#
#  C19H36O7P
# {'C': 19, 'H': 36, 'O': 7, 'P': 1}
# C19H36O7P --- MW (amu): 407.5
#
#  *
# {}
#
#  O4S
# {'O': 4, 'S': 1}
# O4S --- MW (amu): 96.06
#
#  C15H23N6O5S
# {'C': 15, 'H': 23, 'N': 6, 'O': 5, 'S': 1}
# C15H23N6O5S --- MW (amu): 399.4
#
#  C3H6NOR2S
# {'C': 3, 'H': 6, 'N': 1, 'O': 1, 'R': 2, 'S': 1}
# C3H6NOR2S --- MW (amu): 74.09
#
#  O4S
# {'O': 4, 'S': 1}
# O4S --- MW (amu): 96.06
#
#  O4S
# {'O': 4, 'S': 1}
# O4S --- MW (amu): 96.06
#
#  C17H22N3O18P2
# {'C': 17, 'H': 22, 'N': 3, 'O': 18, 'P': 2}
# C17H22N3O18P2 --- MW (amu): 618.3
#
#  C5H4N4O
# {'C': 5, 'H': 4, 'N': 4, 'O': 1}
# C5H4N4O --- MW (amu): 136.1
#
#  C19H36O7P
# {'C': 19, 'H': 36, 'O': 7, 'P': 1}
# C19H36O7P --- MW (amu): 407.5
#
#  C6H4NO2
# {'C': 6, 'H': 4, 'N': 1, 'O': 2}
# C6H4NO2 --- MW (amu): 122.1
#
#  C16H24N2O15P2
# {'C': 16, 'H': 24, 'N': 2, 'O': 15, 'P': 2}
# C16H24N2O15P2 --- MW (amu): 546.3
#
#  C4H4O5
# {'C': 4, 'H': 4, 'O': 5}
# C4H4O5 --- MW (amu): 132.1
#
#  C4H4O5
# {'C': 4, 'H': 4, 'O': 5}
# C4H4O5 --- MW (amu): 132.1
#
#  C21H42NO7P
# {'C': 21, 'H': 42, 'N': 1, 'O': 7, 'P': 1}
# C21H42NO7P --- MW (amu): 451.5
#
#  C6H4NO2
# {'C': 6, 'H': 4, 'N': 1, 'O': 2}
# C6H4NO2 --- MW (amu): 122.1
#
#  C9H12N2O15P3
# {'C': 9, 'H': 12, 'N': 2, 'O': 15, 'P': 3}
# C9H12N2O15P3 --- MW (amu): 481.1
#
#  C4H4O5
# {'C': 4, 'H': 4, 'O': 5}
# C4H4O5 --- MW (amu): 132.1
#
#  C5H4N4O
# {'C': 5, 'H': 4, 'N': 4, 'O': 1}
# C5H4N4O --- MW (amu): 136.1
#
#  C6H4NO2
# {'C': 6, 'H': 4, 'N': 1, 'O': 2}
# C6H4NO2 --- MW (amu): 122.1
#
#  C5H4N4O
# {'C': 5, 'H': 4, 'N': 4, 'O': 1}
# C5H4N4O --- MW (amu): 136.1
#
#  C6H12O6
# {'C': 6, 'H': 12, 'O': 6}
# C6H12O6 --- MW (amu): 180.2
#
#  C3H7O6P
# {'C': 3, 'H': 7, 'O': 6, 'P': 1}
# C3H7O6P --- MW (amu): 170.1
#
#  C3H7O6P
# {'C': 3, 'H': 7, 'O': 6, 'P': 1}
# C3H7O6P --- MW (amu): 170.1
#
#  C5H9O7P
# {'C': 5, 'H': 9, 'O': 7, 'P': 1}
# C5H9O7P --- MW (amu): 212.1
#
#  CH2NO2
# {'C': 1, 'H': 2, 'N': 1, 'O': 2}
# CH2NO2 --- MW (amu): 60.03
#
#  C3H7O6P
# {'C': 3, 'H': 7, 'O': 6, 'P': 1}
# C3H7O6P --- MW (amu): 170.1
#
#  C17H31N2O8PRS
# {'C': 17, 'H': 31, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C17H31N2O8PRS --- MW (amu): 454.5
#
#  C15H21N5O15P2
# {'C': 15, 'H': 21, 'N': 5, 'O': 15, 'P': 2}
# C15H21N5O15P2 --- MW (amu): 573.3
#
#  C35H56N7O17P3S
# {'C': 35, 'H': 56, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C35H56N7O17P3S --- MW (amu): 971.8
#
#  C41H78NO8P
# {'C': 41, 'H': 78, 'N': 1, 'O': 8, 'P': 1}
# C41H78NO8P --- MW (amu): 744.0
#
#  C19H40NO7P
# {'C': 19, 'H': 40, 'N': 1, 'O': 7, 'P': 1}
# C19H40NO7P --- MW (amu): 425.5
#
#  C10H13N5O8P
# {'C': 10, 'H': 13, 'N': 5, 'O': 8, 'P': 1}
# C10H13N5O8P --- MW (amu): 362.2
#
#  *
# {}
#
#  C22H33N4O13
# {'C': 22, 'H': 33, 'N': 4, 'O': 13}
# C22H33N4O13 --- MW (amu): 561.5
#
#  C22H33N4O13
# {'C': 22, 'H': 33, 'N': 4, 'O': 13}
# C22H33N4O13 --- MW (amu): 561.5
#
#  C41H78NO8P
# {'C': 41, 'H': 78, 'N': 1, 'O': 8, 'P': 1}
# C41H78NO8P --- MW (amu): 744.0
#
#  C5H13N2O2
# {'C': 5, 'H': 13, 'N': 2, 'O': 2}
# C5H13N2O2 --- MW (amu): 133.2
#
#  C22H33N4O13
# {'C': 22, 'H': 33, 'N': 4, 'O': 13}
# C22H33N4O13 --- MW (amu): 561.5
#
#  C5H13N2O2
# {'C': 5, 'H': 13, 'N': 2, 'O': 2}
# C5H13N2O2 --- MW (amu): 133.2
#
#  C4H8O
# {'C': 4, 'H': 8, 'O': 1}
# C4H8O --- MW (amu): 72.11
#
#  C3H6O2
# {'C': 3, 'H': 6, 'O': 2}
# C3H6O2 --- MW (amu): 74.08
#
#  C42H41N4O16
# {'C': 42, 'H': 41, 'N': 4, 'O': 16}
# C42H41N4O16 --- MW (amu): 857.8
#
#  C5H13N2O2
# {'C': 5, 'H': 13, 'N': 2, 'O': 2}
# C5H13N2O2 --- MW (amu): 133.2
#
#  C4H9NO4
# {'C': 4, 'H': 9, 'N': 1, 'O': 4}
# C4H9NO4 --- MW (amu): 135.1
#
#  *
# {}
#
#  C8H24N3
# {'C': 8, 'H': 24, 'N': 3}
# C8H24N3 --- MW (amu): 162.3
#
#  C3H7NO2
# {'C': 3, 'H': 7, 'N': 1, 'O': 2}
# C3H7NO2 --- MW (amu): 89.09
#
#  C4H9NO3
# {'C': 4, 'H': 9, 'N': 1, 'O': 3}
# C4H9NO3 --- MW (amu): 119.1
#
#  C9H9O3
# {'C': 9, 'H': 9, 'O': 3}
# C9H9O3 --- MW (amu): 165.2
#
#  C112H204N3O42P3
# {'C': 112, 'H': 204, 'N': 3, 'O': 42, 'P': 3}
# C112H204N3O42P3 --- MW (amu): 2358
#
#  C9H9O3
# {'C': 9, 'H': 9, 'O': 3}
# C9H9O3 --- MW (amu): 165.2
#
#  C3H7NO2
# {'C': 3, 'H': 7, 'N': 1, 'O': 2}
# C3H7NO2 --- MW (amu): 89.09
#
#  C11H12N2O2
# {'C': 11, 'H': 12, 'N': 2, 'O': 2}
# C11H12N2O2 --- MW (amu): 204.2
#
#  C8H15N3O8P
# {'C': 8, 'H': 15, 'N': 3, 'O': 8, 'P': 1}
# C8H15N3O8P --- MW (amu): 312.2
#
#  C11H12N2O2
# {'C': 11, 'H': 12, 'N': 2, 'O': 2}
# C11H12N2O2 --- MW (amu): 204.2
#
#  C11H12N2O2
# {'C': 11, 'H': 12, 'N': 2, 'O': 2}
# C11H12N2O2 --- MW (amu): 204.2
#
#  C5H8O4
# {'C': 5, 'H': 8, 'O': 4}
# C5H8O4 --- MW (amu): 132.1
#
#  C112H204N3O42P3
# {'C': 112, 'H': 204, 'N': 3, 'O': 42, 'P': 3}
# C112H204N3O42P3 --- MW (amu): 2358
#
#  C3H7NO2
# {'C': 3, 'H': 7, 'N': 1, 'O': 2}
# C3H7NO2 --- MW (amu): 89.09
#
#  C9H12N2O12P2
# {'C': 9, 'H': 12, 'N': 2, 'O': 12, 'P': 2}
# C9H12N2O12P2 --- MW (amu): 402.1
#
#  C40H71N3O15P2
# {'C': 40, 'H': 71, 'N': 3, 'O': 15, 'P': 2}
# C40H71N3O15P2 --- MW (amu): 896.0
#
#  C3H6O
# {'C': 3, 'H': 6, 'O': 1}
# C3H6O --- MW (amu): 58.08
#
#  C3H6O
# {'C': 3, 'H': 6, 'O': 1}
# C3H6O --- MW (amu): 58.08
#
#  C50H72O2
# {'C': 50, 'H': 72, 'O': 2}
# C50H72O2 --- MW (amu): 705.1
#
#  C9H9O3
# {'C': 9, 'H': 9, 'O': 3}
# C9H9O3 --- MW (amu): 165.2
#
#  C12H21O14P
# {'C': 12, 'H': 21, 'O': 14, 'P': 1}
# C12H21O14P --- MW (amu): 420.3
#
#  C3H6O
# {'C': 3, 'H': 6, 'O': 1}
# C3H6O --- MW (amu): 58.08
#
#  CHN
# {'C': 1, 'H': 1, 'N': 1}
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# ...
# C34H66O13P2 --- MW (amu): 744.8
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C16H28N2O11
# {'C': 16, 'H': 28, 'N': 2, 'O': 11}
# C16H28N2O11 --- MW (amu): 424.4
#
#  C34H66O13P2
# {'C': 34, 'H': 66, 'O': 13, 'P': 2}
# C34H66O13P2 --- MW (amu): 744.8
#
#  C35H58N7O18P3S
# {'C': 35, 'H': 58, 'N': 7, 'O': 18, 'P': 3, 'S': 1}
# C35H58N7O18P3S --- MW (amu): 989.9
#
#  C18H27N3O15P2
# {'C': 18, 'H': 27, 'N': 3, 'O': 15, 'P': 2}
# C18H27N3O15P2 --- MW (amu): 587.4
#
#  C4H9NO3
# {'C': 4, 'H': 9, 'N': 1, 'O': 3}
# C4H9NO3 --- MW (amu): 119.1
#
#  C7H8N5O3
# {'C': 7, 'H': 8, 'N': 5, 'O': 3}
# C7H8N5O3 --- MW (amu): 210.2
#
#  C4H9NO3
# {'C': 4, 'H': 9, 'N': 1, 'O': 3}
# C4H9NO3 --- MW (amu): 119.1
#
#  C17H32O7P
# {'C': 17, 'H': 32, 'O': 7, 'P': 1}
# C17H32O7P --- MW (amu): 379.4
#
#  C29H53N2O8PRS
# {'C': 29, 'H': 53, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C29H53N2O8PRS --- MW (amu): 620.8
#
#  Cu
# {'Cu': 1}
# Cu --- MW (amu): 63.55
#
#  C2H7NO3S
# {'C': 2, 'H': 7, 'N': 1, 'O': 3, 'S': 1}
# C2H7NO3S --- MW (amu): 125.1
#
#  C11H12Cl2N2O5
# {'C': 11, 'H': 12, 'Cl': 2, 'N': 2, 'O': 5}
# C11H12Cl2N2O5 --- MW (amu): 323.1
#
#  C8H11NO3
# {'C': 8, 'H': 11, 'N': 1, 'O': 3}
# C8H11NO3 --- MW (amu): 169.2
#
#  C63H103NO12P2
# {'C': 63, 'H': 103, 'N': 1, 'O': 12, 'P': 2}
# C63H103NO12P2 --- MW (amu): 1128
#
#  C35H52FeN6O13
# {'C': 35, 'H': 52, 'Fe': 1, 'N': 6, 'O': 13}
# C35H52FeN6O13 --- MW (amu): 820.7
#
#  C2H7NO3S
# {'C': 2, 'H': 7, 'N': 1, 'O': 3, 'S': 1}
# C2H7NO3S --- MW (amu): 125.1
#
#  C11H12Cl2N2O5
# {'C': 11, 'H': 12, 'Cl': 2, 'N': 2, 'O': 5}
# C11H12Cl2N2O5 --- MW (amu): 323.1
#
#  C6H11O6
# {'C': 6, 'H': 11, 'O': 6}
# C6H11O6 --- MW (amu): 179.1
#
#  C8H11NO3
# {'C': 8, 'H': 11, 'N': 1, 'O': 3}
# C8H11NO3 --- MW (amu): 169.2
#
#  C7H14N2O8P
# {'C': 7, 'H': 14, 'N': 2, 'O': 8, 'P': 1}
# C7H14N2O8P --- MW (amu): 285.2
#
#  C9H23N3O
# {'C': 9, 'H': 23, 'N': 3, 'O': 1}
# C9H23N3O --- MW (amu): 189.3
#
#  C2H7NO3S
# {'C': 2, 'H': 7, 'N': 1, 'O': 3, 'S': 1}
# C2H7NO3S --- MW (amu): 125.1
#
#  C35H52FeN6O13
# {'C': 35, 'H': 52, 'Fe': 1, 'N': 6, 'O': 13}
# C35H52FeN6O13 --- MW (amu): 820.7
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C35H52FeN6O13
# {'C': 35, 'H': 52, 'Fe': 1, 'N': 6, 'O': 13}
# C35H52FeN6O13 --- MW (amu): 820.7
#
#  C8H11NO3
# {'C': 8, 'H': 11, 'N': 1, 'O': 3}
# C8H11NO3 --- MW (amu): 169.2
#
#  C27H51N2O8PRS
# {'C': 27, 'H': 51, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C27H51N2O8PRS --- MW (amu): 594.7
#
#  *
# {}
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C37H57N7O20
# {'C': 37, 'H': 57, 'N': 7, 'O': 20}
# C37H57N7O20 --- MW (amu): 919.9
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C29H55N2O9PRS
# {'C': 29, 'H': 55, 'N': 2, 'O': 9, 'P': 1, 'R': 1, 'S': 1}
# C29H55N2O9PRS --- MW (amu): 638.8
#
#  *
# {}
#
#  C37H57N7O20
# {'C': 37, 'H': 57, 'N': 7, 'O': 20}
# C37H57N7O20 --- MW (amu): 919.9
#
#  C23H48NO7P
# {'C': 23, 'H': 48, 'N': 1, 'O': 7, 'P': 1}
# C23H48NO7P --- MW (amu): 481.6
#
#  C7H11N2O3
# {'C': 7, 'H': 11, 'N': 2, 'O': 3}
# C7H11N2O3 --- MW (amu): 171.2
#
#  C5H7O4
# {'C': 5, 'H': 7, 'O': 4}
# C5H7O4 --- MW (amu): 131.1
#
#  C12H15O10P
# {'C': 12, 'H': 15, 'O': 10, 'P': 1}
# C12H15O10P --- MW (amu): 350.2
#
#  C30H27N3O15
# {'C': 30, 'H': 27, 'N': 3, 'O': 15}
# C30H27N3O15 --- MW (amu): 669.5
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C35H56N6O13
# {'C': 35, 'H': 56, 'N': 6, 'O': 13}
# C35H56N6O13 --- MW (amu): 768.9
#
#  C30H27N3O15
# {'C': 30, 'H': 27, 'N': 3, 'O': 15}
# C30H27N3O15 --- MW (amu): 669.5
#
#  C35H56N6O13
# {'C': 35, 'H': 56, 'N': 6, 'O': 13}
# C35H56N6O13 --- MW (amu): 768.9
#
#  C4H5O3
# {'C': 4, 'H': 5, 'O': 3}
# C4H5O3 --- MW (amu): 101.1
#
#  C9H13N3O5
# {'C': 9, 'H': 13, 'N': 3, 'O': 5}
# C9H13N3O5 --- MW (amu): 243.2
#
#  C10H10NO6
# {'C': 10, 'H': 10, 'N': 1, 'O': 6}
# C10H10NO6 --- MW (amu): 240.2
#
#  C8H7N
# {'C': 8, 'H': 7, 'N': 1}
# C8H7N --- MW (amu): 117.1
#
#  *
# {}
#
#  C30H27N3O15
# {'C': 30, 'H': 27, 'N': 3, 'O': 15}
# C30H27N3O15 --- MW (amu): 669.5
#
#  C6H9O7
# {'C': 6, 'H': 9, 'O': 7}
# C6H9O7 --- MW (amu): 193.1
#
#  C6H9O7
# {'C': 6, 'H': 9, 'O': 7}
# C6H9O7 --- MW (amu): 193.1
#
#  C8H8O3
# {'C': 8, 'H': 8, 'O': 3}
# C8H8O3 --- MW (amu): 152.1
#
#  CH3O3S
# {'C': 1, 'H': 3, 'O': 3, 'S': 1}
# CH3O3S --- MW (amu): 95.10
#
#  CH3O3S
# {'C': 1, 'H': 3, 'O': 3, 'S': 1}
# CH3O3S --- MW (amu): 95.10
#
#  Mn
# {'Mn': 1}
# Mn --- MW (amu): 54.94
#
#  C8H8O3
# {'C': 8, 'H': 8, 'O': 3}
# C8H8O3 --- MW (amu): 152.1
#
#  CH3O3S
# {'C': 1, 'H': 3, 'O': 3, 'S': 1}
# CH3O3S --- MW (amu): 95.10
#
#  C33H52N7O17P3S
# {'C': 33, 'H': 52, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C33H52N7O17P3S --- MW (amu): 943.8
#
#  Mn
# {'Mn': 1}
# Mn --- MW (amu): 54.94
#
#  C27H40N7O18P3S
# {'C': 27, 'H': 40, 'N': 7, 'O': 18, 'P': 3, 'S': 1}
# C27H40N7O18P3S --- MW (amu): 875.6
#
#  C5H6O5
# {'C': 5, 'H': 6, 'O': 5}
# C5H6O5 --- MW (amu): 146.1
#
#  C35H56N6O13
# {'C': 35, 'H': 56, 'N': 6, 'O': 13}
# C35H56N6O13 --- MW (amu): 768.9
#
#  Mn
# {'Mn': 1}
# Mn --- MW (amu): 54.94
#
#  C14H22N3O17P3
# {'C': 14, 'H': 22, 'N': 3, 'O': 17, 'P': 3}
# C14H22N3O17P3 --- MW (amu): 597.3
#
#  C6H11O2
# {'C': 6, 'H': 11, 'O': 2}
# C6H11O2 --- MW (amu): 115.2
#
#  C8H10NO6P
# {'C': 8, 'H': 10, 'N': 1, 'O': 6, 'P': 1}
# C8H10NO6P --- MW (amu): 247.1
#
#  *
# {}
#
#  C6H11O2
# {'C': 6, 'H': 11, 'O': 2}
# C6H11O2 --- MW (amu): 115.2
#
#  C6H8O9P
# {'C': 6, 'H': 8, 'O': 9, 'P': 1}
# C6H8O9P --- MW (amu): 255.1
#
#  C6H9O4
# {'C': 6, 'H': 9, 'O': 4}
# C6H9O4 --- MW (amu): 145.1
#
#  C6H11O2
# {'C': 6, 'H': 11, 'O': 2}
# C6H11O2 --- MW (amu): 115.2
#
#  C72H102CoN18O17P
# {'C': 72, 'H': 102, 'Co': 1, 'N': 18, 'O': 17, 'P': 1}
# C72H102CoN18O17P --- MW (amu): 1582
#
#  H2O4Se
# {'H': 2, 'O': 4, 'Se': 1}
# H2O4Se --- MW (amu): 145.0
#
#  C11H12NO6P
# {'C': 11, 'H': 12, 'N': 1, 'O': 6, 'P': 1}
# C11H12NO6P --- MW (amu): 285.2
#
#  C72H102CoN18O17P
# {'C': 72, 'H': 102, 'Co': 1, 'N': 18, 'O': 17, 'P': 1}
# C72H102CoN18O17P --- MW (amu): 1582
#
#  H2O4Se
# {'H': 2, 'O': 4, 'Se': 1}
# H2O4Se --- MW (amu): 145.0
#
#  C8H7N
# {'C': 8, 'H': 7, 'N': 1}
# C8H7N --- MW (amu): 117.1
#
#  C8H7N
# {'C': 8, 'H': 7, 'N': 1}
# C8H7N --- MW (amu): 117.1
#
#  C10H12N4O15P3
# {'C': 10, 'H': 12, 'N': 4, 'O': 15, 'P': 3}
# C10H12N4O15P3 --- MW (amu): 521.1
#
#  C72H102CoN18O17P
# {'C': 72, 'H': 102, 'Co': 1, 'N': 18, 'O': 17, 'P': 1}
# C72H102CoN18O17P --- MW (amu): 1582
#
#  C7H10O5
# {'C': 7, 'H': 10, 'O': 5}
# C7H10O5 --- MW (amu): 174.2
#
#  C2H6OS
# {'C': 2, 'H': 6, 'O': 1, 'S': 1}
# C2H6OS --- MW (amu): 78.13
#
#  C2H6OS
# {'C': 2, 'H': 6, 'O': 1, 'S': 1}
# C2H6OS --- MW (amu): 78.13
#
#  C74H112N14O39
# {'C': 74, 'H': 112, 'N': 14, 'O': 39}
# C74H112N14O39 --- MW (amu): 1822
#
#  H2O4Se
# {'H': 2, 'O': 4, 'Se': 1}
# H2O4Se --- MW (amu): 145.0
#
#  C15H19N2O18P2
# {'C': 15, 'H': 19, 'N': 2, 'O': 18, 'P': 2}
# C15H19N2O18P2 --- MW (amu): 577.3
#
#  C15H19N2O18P2
# {'C': 15, 'H': 19, 'N': 2, 'O': 18, 'P': 2}
# C15H19N2O18P2 --- MW (amu): 577.3
#
#  C15H19N2O18P2
# {'C': 15, 'H': 19, 'N': 2, 'O': 18, 'P': 2}
# C15H19N2O18P2 --- MW (amu): 577.3
#
#  C3H5NO3
# {'C': 3, 'H': 5, 'N': 1, 'O': 3}
# C3H5NO3 --- MW (amu): 103.1
#
#  C39H67N7O18P3S
# {'C': 39, 'H': 67, 'N': 7, 'O': 18, 'P': 3, 'S': 1}
# C39H67N7O18P3S --- MW (amu): 1047
#
#  C17H21N4O9P
# {'C': 17, 'H': 21, 'N': 4, 'O': 9, 'P': 1}
# C17H21N4O9P --- MW (amu): 456.3
#
#  C7H8O8P
# {'C': 7, 'H': 8, 'O': 8, 'P': 1}
# C7H8O8P --- MW (amu): 251.1
#
#  CH4O3P
# {'C': 1, 'H': 4, 'O': 3, 'P': 1}
# CH4O3P --- MW (amu): 95.01
#
#  CH4O3P
# {'C': 1, 'H': 4, 'O': 3, 'P': 1}
# CH4O3P --- MW (amu): 95.01
#
#  C9H11N2O8P
# {'C': 9, 'H': 11, 'N': 2, 'O': 8, 'P': 1}
# C9H11N2O8P --- MW (amu): 306.2
#
#  *
# {}
#
#  C2H6OS
# {'C': 2, 'H': 6, 'O': 1, 'S': 1}
# C2H6OS --- MW (amu): 78.13
#
#  C84H148N2O37P2
# {'C': 84, 'H': 148, 'N': 2, 'O': 37, 'P': 2}
# C84H148N2O37P2 --- MW (amu): 1840
#
#  C5H10O5
# {'C': 5, 'H': 10, 'O': 5}
# C5H10O5 --- MW (amu): 150.1
#
#  C84H148N2O37P2
# {'C': 84, 'H': 148, 'N': 2, 'O': 37, 'P': 2}
# C84H148N2O37P2 --- MW (amu): 1840
#
#  NO3
# {'N': 1, 'O': 3}
# NO3 --- MW (amu): 62.00
#
#  C9H11N2O8P
# {'C': 9, 'H': 11, 'N': 2, 'O': 8, 'P': 1}
# C9H11N2O8P --- MW (amu): 306.2
#
#  NO3
# {'N': 1, 'O': 3}
# NO3 --- MW (amu): 62.00
#
#  C3H4NO2
# {'C': 3, 'H': 4, 'N': 1, 'O': 2}
# C3H4NO2 --- MW (amu): 86.07
#
#  C5H16N4
# {'C': 5, 'H': 16, 'N': 4}
# C5H16N4 --- MW (amu): 132.2
#
#  CH4O3P
# {'C': 1, 'H': 4, 'O': 3, 'P': 1}
# CH4O3P --- MW (amu): 95.01
#
#  C5H16N4
# {'C': 5, 'H': 16, 'N': 4}
# C5H16N4 --- MW (amu): 132.2
#
#  HS
# {'H': 1, 'S': 1}
# HS --- MW (amu): 33.07
#
#  C9H11N2O8P
# {'C': 9, 'H': 11, 'N': 2, 'O': 8, 'P': 1}
# C9H11N2O8P --- MW (amu): 306.2
#
#  HS
# {'H': 1, 'S': 1}
# HS --- MW (amu): 33.07
#
#  NO3
# {'N': 1, 'O': 3}
# NO3 --- MW (amu): 62.00
#
#  H2O
# {'H': 2, 'O': 1}
# H2O --- MW (amu): 18.02
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  H2O
# {'H': 2, 'O': 1}
# H2O --- MW (amu): 18.02
#
#  HS
# {'H': 1, 'S': 1}
# HS --- MW (amu): 33.07
#
#  C25H45N2O8PRS
# {'C': 25, 'H': 45, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C25H45N2O8PRS --- MW (amu): 564.7
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C3H9NO
# {'C': 3, 'H': 9, 'N': 1, 'O': 1}
# C3H9NO --- MW (amu): 75.11
#
#  C6H11O9P
# {'C': 6, 'H': 11, 'O': 9, 'P': 1}
# C6H11O9P --- MW (amu): 258.1
#
#  C15H30O7P
# {'C': 15, 'H': 30, 'O': 7, 'P': 1}
# C15H30O7P --- MW (amu): 353.4
#
#  H2O
# {'H': 2, 'O': 1}
# H2O --- MW (amu): 18.02
#
#  C36H40N4O8
# {'C': 36, 'H': 40, 'N': 4, 'O': 8}
# C36H40N4O8 --- MW (amu): 656.7
#
#  C15H30O7P
# {'C': 15, 'H': 30, 'O': 7, 'P': 1}
# C15H30O7P --- MW (amu): 353.4
#
#  C11H16NO7
# {'C': 11, 'H': 16, 'N': 1, 'O': 7}
# C11H16NO7 --- MW (amu): 274.2
#
#  C8H8NO6P
# {'C': 8, 'H': 8, 'N': 1, 'O': 6, 'P': 1}
# C8H8NO6P --- MW (amu): 245.1
#
#  C84H148N2O37P2
# {'C': 84, 'H': 148, 'N': 2, 'O': 37, 'P': 2}
# C84H148N2O37P2 --- MW (amu): 1840
#
#  C89H145NO32P2
# {'C': 89, 'H': 145, 'N': 1, 'O': 32, 'P': 2}
# C89H145NO32P2 --- MW (amu): 1803
#
#  C46H70O2
# {'C': 46, 'H': 70, 'O': 2}
# C46H70O2 --- MW (amu): 655.0
#
#  C89H145NO32P2
# {'C': 89, 'H': 145, 'N': 1, 'O': 32, 'P': 2}
# C89H145NO32P2 --- MW (amu): 1803
#
#  C24H35N7O17P3S
# {'C': 24, 'H': 35, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C24H35N7O17P3S --- MW (amu): 818.6
#
#  H2O2
# {'H': 2, 'O': 2}
# H2O2 --- MW (amu): 34.01
#
#  C12H21O14P
# {'C': 12, 'H': 21, 'O': 14, 'P': 1}
# C12H21O14P --- MW (amu): 420.3
#
#  *
# {}
#
#  C5H10O5
# {'C': 5, 'H': 10, 'O': 5}
# C5H10O5 --- MW (amu): 150.1
#
#  H2O2
# {'H': 2, 'O': 2}
# H2O2 --- MW (amu): 34.01
#
#  C139H241N2O70P4
# {'C': 139, 'H': 241, 'N': 2, 'O': 70, 'P': 4}
# C139H241N2O70P4 --- MW (amu): 3184
#
#  H
# {'H': 1}
# H --- MW (amu): 1.008
#
#  CHO2
# {'C': 1, 'H': 1, 'O': 2}
# CHO2 --- MW (amu): 45.02
#
#  *
# {}
#
#  *
# {}
#
#  H2O2
# {'H': 2, 'O': 2}
# H2O2 --- MW (amu): 34.01
#
#  C3H5O4
# {'C': 3, 'H': 5, 'O': 4}
# C3H5O4 --- MW (amu): 105.1
#
#  C3H9NO
# {'C': 3, 'H': 9, 'N': 1, 'O': 1}
# C3H9NO --- MW (amu): 75.11
#
#  C10H12N5O17P4
# {'C': 10, 'H': 12, 'N': 5, 'O': 17, 'P': 4}
# C10H12N5O17P4 --- MW (amu): 598.1
#
#  C3H9NO
# {'C': 3, 'H': 9, 'N': 1, 'O': 1}
# C3H9NO --- MW (amu): 75.11
#
#  C23H44N2O8PRS
# {'C': 23, 'H': 44, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C23H44N2O8PRS --- MW (amu): 539.6
#
#  C6H9O5
# {'C': 6, 'H': 9, 'O': 5}
# C6H9O5 --- MW (amu): 161.1
#
#  C35H57N7O17P3S
# {'C': 35, 'H': 57, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C35H57N7O17P3S --- MW (amu): 972.9
#
#  C34H32N4O4
# {'C': 34, 'H': 32, 'N': 4, 'O': 4}
# C34H32N4O4 --- MW (amu): 560.6
#
#  C12H16N5O3
# {'C': 12, 'H': 16, 'N': 5, 'O': 3}
# C12H16N5O3 --- MW (amu): 278.3
#
#  C3H5O4
# {'C': 3, 'H': 5, 'O': 4}
# C3H5O4 --- MW (amu): 105.1
#
#  C3H5O4
# {'C': 3, 'H': 5, 'O': 4}
# C3H5O4 --- MW (amu): 105.1
#
#  C7H9O5
# {'C': 7, 'H': 9, 'O': 5}
# C7H9O5 --- MW (amu): 173.1
#
#  C5H16N4
# {'C': 5, 'H': 16, 'N': 4}
# C5H16N4 --- MW (amu): 132.2
#
#  C27H49N2O8PRS
# {'C': 27, 'H': 49, 'N': 2, 'O': 8, 'P': 1, 'R': 1, 'S': 1}
# C27H49N2O8PRS --- MW (amu): 592.7
#
#  C8H13N2O9P
# {'C': 8, 'H': 13, 'N': 2, 'O': 9, 'P': 1}
# C8H13N2O9P --- MW (amu): 312.2
#
#  C27H42N7O20P3S
# {'C': 27, 'H': 42, 'N': 7, 'O': 20, 'P': 3, 'S': 1}
# C27H42N7O20P3S --- MW (amu): 909.6
#
#  C4H6O8P
# {'C': 4, 'H': 6, 'O': 8, 'P': 1}
# C4H6O8P --- MW (amu): 213.1
#
#  H
# {'H': 1}
# H --- MW (amu): 1.008
#
#  H
# {'H': 1}
# H --- MW (amu): 1.008
#
#  C7H9O5
# {'C': 7, 'H': 9, 'O': 5}
# C7H9O5 --- MW (amu): 173.1
#
#  C6H6O2
# {'C': 6, 'H': 6, 'O': 2}
# C6H6O2 --- MW (amu): 110.1
#
#  C5H10O5
# {'C': 5, 'H': 10, 'O': 5}
# C5H10O5 --- MW (amu): 150.1
#
#  C27H42N7O17P3S
# {'C': 27, 'H': 42, 'N': 7, 'O': 17, 'P': 3, 'S': 1}
# C27H42N7O17P3S --- MW (amu): 861.6
#
#  C7H9O5
# {'C': 7, 'H': 9, 'O': 5}
# C7H9O5 --- MW (amu): 173.1
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in formula '*'
#   warn(f"invalid character '*' found in formula '{self.formula}'")
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
# C:\Users\Andrew Freiburger\Documents\UVic Civil Engineering\PHREEQC\mw\chemw\mw.py:230: UserWarning: The character R is not an element.
#   if formula[ch_number] in ['*', "", None]:
