# %%
from pprint import pprint
# import chemw
# %run ../chemw/mw.py

test_chemicals = {
    'C60': 720.6,
    'C60_H120_O2': 873.6,
    'Na2.43_Cl_(OH)2_(OH)1.2_(OH)': 162.7,
    'Na2.43Cl(Ca(OH)2)1.2':180.2,
    'Na2.43Cl:2H2O': 127.3,
    'Na2.43Cl2.5:2H2O': 180.5,
    'CaCl2:(MgCl2)2:12H2O': 517.6,
    'Na2SO4:3K2SO4': 664.8,
    'K2SO4:CaSO4:H2O': 328.4,
    'Na.96Al.96Si2.04O6:H2O ': 219.2,
    'Ca1.019Na.136K.006Al2.18Si6.82O18:7.33H2O': 714.4
}
chem_mw = ChemMW()
for chem in test_chemicals:
    chem_mw.mass(chem)
    print('elemental_masses', )
    pprint(chem_mw.element_masses)
    print('elemental_proportions', )
    pprint(chem_mw.proportions)
# Out:
# C60 --- MW (amu): 720.642
# elemental_masses
# {'C': 720.642}
# elemental_proportions
# {'C': 1.0}
#
# C60H120O2 --- MW (amu): 873.5936
# elemental_masses
# {'C': 720.642, 'H': 120.95280000000001, 'O': 31.9988}
# elemental_proportions
# {'C': 0.8249167576319241, 'H': 0.13845431102059355, 'O': 0.036628931347482394}
#
# Na2.43Cl(OH)2(OH)1.2(OH) --- MW (amu): 162.7489691
# elemental_masses
# {'Cl': 35.453, 'H': 3.02382, 'Na': 55.8651411, 'O': 47.9982}
# elemental_proportions
# {'Cl': 0.24907236106816522,
#  'H': 0.021243617940516723,
#  'Na': 0.39247630934429234,
#  'O': 0.3372077116470258}
#
# Na2.43Cl(Ca(OH)2)1.2 --- MW (amu): 180.22935710000002
# elemental_masses
# {'Ca': 40.078, 'Cl': 35.453, 'H': 1.00794, 'Na': 55.8651411, 'O': 15.9994}
# elemental_proportions
# {'Ca': 0.2700610504749137,
#  'Cl': 0.23889601333617233,
#  'H': 0.006791889196459017,
#  'Na': 0.3764409074902758,
#  'O': 0.10781013950217909}
#
# Na2.43Cl:2H2O --- MW (amu): 127.3487011
# elemental_masses
# {'Cl': 35.453, 'H': 2.01588, 'Na': 55.8651411, 'O': 15.9994}
# elemental_proportions
# {'Cl': 0.3242649836007007,
#  'H': 0.01843791202834684,
#  'Na': 0.5109612462314143,
#  'O': 0.14633585813953828}
#
# Na2.43Cl2.5:2H2O --- MW (amu): 180.52820110000002
# elemental_masses
# {'Cl': 88.63250000000001, 'H': 2.01588, 'Na': 55.8651411, 'O': 15.9994}
# elemental_proportions
# {'Cl': 0.5453874030450861,
#  'H': 0.012404429053118532,
#  'Na': 0.34375814994811504,
#  'O': 0.0984500179536801}
#
# CaCl2:(MgCl2)2:12H2O --- MW (amu): 517.58936
# elemental_masses
# {'Ca': 40.078, 'Cl': 141.812, 'H': 2.01588, 'Mg': 24.305, 'O': 15.9994}
# elemental_proportions
# {'Ca': 0.17875183956774862,
#  'Cl': 0.632495530534996,
#  'H': 0.008991023961969985,
#  'Mg': 0.10840270124991591,
#  'O': 0.07135890468536946}
#
# Na2SO4:3K2SO4 --- MW (amu): 664.81974
# elemental_masses
# {'K': 78.1966, 'Na': 45.97954, 'O': 127.9952, 'S': 64.13}
# elemental_proportions
# {'K': 0.2472218423102476,
#  'Na': 0.14536625105666642,
#  'O': 0.4046622123067832,
#  'S': 0.20274969432630288}
#
# K2SO4:CaSO4:H2O --- MW (amu): 328.41507999999993
# elemental_masses
# {'Ca': 40.078, 'H': 2.01588, 'K': 78.1966, 'O': 143.9946, 'S': 64.13}
# elemental_proportions
# {'Ca': 0.12203459110342926,
#  'H': 0.006138207782663331,
#  'K': 0.2381029519107345,
#  'O': 0.43845306981640436,
#  'S': 0.19527117938676875}
#
# Na.96Al.96Si2.04O6:H2O  --- MW (amu): 219.27855568
# elemental_masses
# {'Al': 25.90227648,
#  'H': 2.01588,
#  'Na': 22.0701792,
#  'O': 111.99579999999999,
#  'Si': 57.29442}
# elemental_proportions
# {'Al': 0.1181249867305766,
#  'H': 0.009193238224999241,
#  'Na': 0.10064905403795024,
#  'O': 0.5107467059544069,
#  'Si': 0.26128601505206706}
#
# Ca1.019Na.136K.006Al2.18Si6.82O18:7.33H2O --- MW (amu): 714.60474576
# elemental_masses
# {'Al': 58.81975284000001,
#  'Ca': 40.839482,
#  'H': 2.01588,
#  'K': 0.23458980000000001,
#  'Na': 3.12660872,
#  'O': 303.98859999999996,
#  'Si': 191.54311}
# elemental_proportions
# {'Al': 0.09794020086337753,
#  'Ca': 0.06800142600252874,
#  'H': 0.003356622266902839,
#  'K': 0.0003906132042920628,
#  'Na': 0.005206085902655209,
#  'O': 0.5061684741376571,
#  'Si': 0.31893657762258654}
